# %%
import os
import numpy as np

import math
from collections import Counter

def komsu_oylama(filepath, k=5, radius=None, alpha=0.75, weight=True):
    """
    • radius=None  → k-en yakın; radius=px  → yarıçap içinde
    • weight=True  → 1/dist ağırlıklı oy; False → düz sayım
    • alpha        → baskın sınıf oran eşiği (0–1). Karşılanmazsa kutu değişmez
    """
    import math
    from collections import defaultdict, Counter

    with open(filepath) as f:
        lines = [l.strip() for l in f if l.strip()]

    entries, centers = [], []
    for l in lines:
        p   = l.split()
        cls = int(float(p[0]))
        cx, cy, w, h = map(float, p[1:5])
        conf = float(p[5]) if len(p) > 5 else None
        entries.append([cls, (cx, cy, w, h), conf])
        centers.append((cx, cy))

    new_cls = []
    for i, (cls_i, (cx_i, cy_i, w_i, h_i), _) in enumerate(entries):
        if cls_i == 4:                 # class 4'u koru
            new_cls.append(cls_i)
            continue

        # uzaklık listesi
        dists = [(math.hypot(cx_i - cx_j, cy_i - cy_j), j)
                 for j, (cx_j, cy_j) in enumerate(centers) if j != i]
        dists.sort(key=lambda x: x[0])

        # komşu seçim stratejisi
        neighbors = []
        if radius is not None:
            neighbors = [j for d, j in dists if d <= radius]
        else:
            neighbors = [j for _, j in dists[:k]]

        if not neighbors:
            new_cls.append(cls_i)
            continue

        # oy toplama
        scores = defaultdict(float)
        for j in neighbors:
            cls_j = entries[j][0]
            wght = 1.0 / (dists[[idx for idx, jj in enumerate(neighbors) if jj == j][0]][0] + 1e-6) if weight else 1.0
            scores[cls_j] += wght

        # kazanan sınıf
        winner, win_score = max(scores.items(), key=lambda x: x[1])
        total_score = sum(scores.values())

        if win_score / total_score >= alpha:
            new_cls.append(winner)
        else:
            new_cls.append(cls_i)

    # dosyayı güncelle
    with open(filepath, "w") as f:
        for (old_cls, box, conf), cls in zip(entries, new_cls):
            line = f"{cls} {' '.join(f'{x:.6f}' for x in box)}"
            if conf is not None:
                line += f" {conf:.6f}"
            f.write(line + "\n")

def compute_iou(box1, box2):
    x1_min = box1[0] - box1[2] / 2
    y1_min = box1[1] - box1[3] / 2
    x1_max = box1[0] + box1[2] / 2
    y1_max = box1[1] + box1[3] / 2

    x2_min = box2[0] - box2[2] / 2
    y2_min = box2[1] - box2[3] / 2
    x2_max = box2[0] + box2[2] / 2
    y2_max = box2[1] + box2[3] / 2

    inter_x_min = max(x1_min, x2_min)
    inter_y_min = max(y1_min, y2_min)
    inter_x_max = min(x1_max, x2_max)
    inter_y_max = min(y1_max, y2_max)

    inter_area = max(0, inter_x_max - inter_x_min) * max(0, inter_y_max - inter_y_min)
    area1 = (x1_max - x1_min) * (y1_max - y1_min)
    area2 = (x2_max - x2_min) * (y2_max - y2_min)

    union_area = area1 + area2 - inter_area
    return inter_area / union_area if union_area > 0 else 0

def remove_duplicates_from_file(filepath, iou_threshold=0.9):
    #print(f"İşleniyor: {filepath}")
    with open(filepath, 'r') as f:
        lines = f.readlines()

    boxes = []
    for line in lines:
        parts = line.strip().split()
        cls = int(parts[0])
        box   = list(map(float, parts[1:5]))  
        boxes.append((cls, box, line.strip()))

    keep = []
    used = [False] * len(boxes)
    
    for i in range(len(boxes)):
        if used[i]:
            continue
        cls1, box1, original1 = boxes[i]
        keep.append((cls1, box1))
        used[i] = True          # ← eklendi
        for j in range(i + 1, len(boxes)):
            cls2, box2, original2 = boxes[j]
            if not used[j]:
                iou = compute_iou(box1, box2)
                if iou > iou_threshold:
                    used[j] = True
                    print(f"[{os.path.basename(filepath)}] Silinen: {original2}  (IoU={iou:.2f})")

    with open(filepath, 'w') as f:
        for cls, box in keep:
            f.write(f"{cls} {' '.join(map(str, box))}\n")

def process_labels_folder(labels_folder, iou_threshold=0.7):
    for filename in os.listdir(labels_folder):
        if filename.endswith('.txt') and filename != "classes.txt":
            filepath = os.path.join(labels_folder, filename)

            # 1) önce KOPYA kutuları sil
            remove_duplicates_from_file(filepath, iou_threshold)

            # 2) sonra komşu oylaması
            #komsu_oylama(filepath, k=10, radius=None, alpha=0.85, weight=True)        # <-- DÜZELTİLDİ

            print(f"Tamamlandı: {filename}\n")


if __name__ == "__main__":
    labels_path = r"C:\Users\524ha\Desktop\Resources\data_managment\notebooks\2010\unlabeled_1\labels"  # Bu klasör yolunu gerektiği gibi değiştir
    
    iou_threshold = 0.5     # Buradan ayarlanabilir
    process_labels_folder(labels_path, iou_threshold)
# Out:
# Tamamlandı: 0508_000003.txt
#
# Tamamlandı: 0508_000006.txt
#
# Tamamlandı: 0508_000009.txt
#
# Tamamlandı: 0508_000012.txt
#
# Tamamlandı: 0508_000015.txt
#
# Tamamlandı: 0508_000018.txt
#
# Tamamlandı: 0508_000021.txt
#
# Tamamlandı: 0508_000024.txt
#
# [0508_000027.txt] Silinen: 3 0.329167 0.533333 0.172917 0.314815  (IoU=0.98)
# Tamamlandı: 0508_000027.txt
#
# Tamamlandı: 0508_000030.txt
#
# Tamamlandı: 0508_000033.txt
#
# Tamamlandı: 0508_000036.txt
#
# Tamamlandı: 0508_000039.txt
#
# Tamamlandı: 0508_000042.txt
#
# Tamamlandı: 0508_000045.txt
#
# [0508_000048.txt] Silinen: 5 0.203906 0.490741 0.142187 0.296296  (IoU=0.98)
# Tamamlandı: 0508_000048.txt
#
# Tamamlandı: 0508_000051.txt
#
# Tamamlandı: 0508_000054.txt
#
# Tamamlandı: 0508_000057.txt
#
# Tamamlandı: 0508_000060.txt
#
# Tamamlandı: 0508_000063.txt
#
# Tamamlandı: 0508_000066.txt
#
# [0508_000069.txt] Silinen: 5 0.436979 0.543519 0.181250 0.325926  (IoU=0.98)
# Tamamlandı: 0508_000069.txt
#
# Tamamlandı: 0508_000072.txt
#
# Tamamlandı: 0508_000075.txt
#
# Tamamlandı: 0508_000078.txt
#
# Tamamlandı: 0508_000081.txt
#
# Tamamlandı: 0508_000084.txt
#
# Tamamlandı: 0508_000087.txt
#
# Tamamlandı: 0508_000090.txt
#
# Tamamlandı: 0508_000093.txt
#
# Tamamlandı: 0508_000096.txt
#
# Tamamlandı: 0508_000099.txt
#
# Tamamlandı: 0508_000102.txt
#
# Tamamlandı: 0508_000105.txt
#
# Tamamlandı: 0508_000108.txt
#
# Tamamlandı: 0508_000111.txt
#
# Tamamlandı: 0508_000114.txt
#
# Tamamlandı: 0508_000117.txt
#
# Tamamlandı: 0508_000120.txt
#
# Tamamlandı: 0508_000123.txt
#
# Tamamlandı: 0508_000126.txt
#
# Tamamlandı: 0508_000129.txt
#
# Tamamlandı: 0508_000132.txt
#
# Tamamlandı: 0508_000135.txt
#
# Tamamlandı: 0508_000138.txt
#
# Tamamlandı: 0508_000141.txt
#
# Tamamlandı: 0508_000144.txt
#
# Tamamlandı: 0508_000147.txt
#
# Tamamlandı: 0508_000150.txt
#
# Tamamlandı: 0508_000153.txt
#
# Tamamlandı: 0508_000156.txt
#
# Tamamlandı: 0508_000159.txt
#
# Tamamlandı: 0508_000162.txt
#
# Tamamlandı: 0508_000165.txt
#
# Tamamlandı: 0508_000168.txt
#
# Tamamlandı: 0508_000171.txt
#
# Tamamlandı: 0508_000174.txt
#
# Tamamlandı: 0508_000177.txt
#
# Tamamlandı: 0508_000180.txt
#
# Tamamlandı: 0508_000183.txt
#
# Tamamlandı: 0508_000186.txt
#
# Tamamlandı: 0508_000189.txt
#
# Tamamlandı: 0508_000192.txt
#
# Tamamlandı: 0508_000195.txt
#
# Tamamlandı: 0508_000198.txt
#
# Tamamlandı: 0508_000201.txt
#
# Tamamlandı: 0508_000204.txt
#
# Tamamlandı: 0508_000207.txt
#
# Tamamlandı: 0508_000210.txt
#
# Tamamlandı: 0508_000213.txt
#
# Tamamlandı: 0508_000216.txt
#
# Tamamlandı: 0508_000219.txt
#
# Tamamlandı: 0508_000222.txt
#
# Tamamlandı: 0508_000225.txt
#
# Tamamlandı: 0508_000228.txt
#
# Tamamlandı: 0508_000231.txt
#
# [0508_000234.txt] Silinen: 5 0.755208 0.515741 0.142708 0.272222  (IoU=0.98)
# Tamamlandı: 0508_000234.txt
#
# Tamamlandı: 0508_000237.txt
#
# [0508_000240.txt] Silinen: 3 0.819271 0.493981 0.131250 0.265741  (IoU=0.99)
# Tamamlandı: 0508_000240.txt
#
# [0508_000243.txt] Silinen: 5 0.841406 0.487500 0.125521 0.263889  (IoU=0.99)
# Tamamlandı: 0508_000243.txt
#
# Tamamlandı: 0508_000246.txt
#
# Tamamlandı: 0508_000249.txt
#
# Tamamlandı: 0508_000252.txt
#
# Tamamlandı: 0508_000255.txt
#
# Tamamlandı: 0508_000258.txt
#
# Tamamlandı: 0508_000261.txt
#
# Tamamlandı: 0508_000264.txt
#
# Tamamlandı: 0508_000267.txt
#
# Tamamlandı: 0508_000270.txt
#
# Tamamlandı: 0508_000273.txt
#
# Tamamlandı: 0508_000276.txt
#
# Tamamlandı: 0508_000279.txt
#
# Tamamlandı: 0508_000282.txt
#
# Tamamlandı: 0508_000285.txt
#
# Tamamlandı: 0508_000288.txt
#
# Tamamlandı: 0508_000291.txt
#
# Tamamlandı: 0508_000294.txt
#
# Tamamlandı: 0508_000297.txt
#
# Tamamlandı: 0508_000300.txt
#
# Tamamlandı: 0508_000303.txt
#
# Tamamlandı: 0508_000306.txt
#
# Tamamlandı: 0508_000309.txt
#
# Tamamlandı: 0508_000312.txt
#
# Tamamlandı: 0508_000315.txt
#
# Tamamlandı: 0508_000318.txt
#
# Tamamlandı: 0508_000321.txt
#
# Tamamlandı: 0508_000324.txt
#
# Tamamlandı: 0508_000327.txt
#
# Tamamlandı: 0508_000330.txt
#
# Tamamlandı: 0508_000333.txt
#
# Tamamlandı: 0508_000336.txt
#
# Tamamlandı: 0508_000339.txt
#
# Tamamlandı: 0508_000342.txt
#
# Tamamlandı: 0508_000345.txt
#
# Tamamlandı: 0508_000348.txt
#
# Tamamlandı: 0508_000351.txt
#
# Tamamlandı: 0508_000354.txt
#
# Tamamlandı: 0508_000357.txt
#
# Tamamlandı: 0508_000360.txt
#
# Tamamlandı: 0508_000363.txt
#
# Tamamlandı: 0508_000366.txt
#
# Tamamlandı: 0508_000369.txt
#
# Tamamlandı: 0508_000372.txt
#
# Tamamlandı: 0508_000375.txt
#
# Tamamlandı: 0508_000378.txt
#
# Tamamlandı: 0508_000381.txt
#
# Tamamlandı: 0508_000384.txt
#
# Tamamlandı: 0508_000387.txt
#
# Tamamlandı: 0508_000390.txt
#
# Tamamlandı: 0508_000393.txt
#
# Tamamlandı: 0508_000396.txt
#
# Tamamlandı: 0508_000399.txt
#
# Tamamlandı: 0508_000402.txt
#
# Tamamlandı: 0508_000405.txt
#
# Tamamlandı: 0508_000408.txt
#
# Tamamlandı: 0508_000411.txt
#
# Tamamlandı: 0508_000414.txt
#
# Tamamlandı: 0508_000417.txt
#
# Tamamlandı: 0508_000420.txt
#
# Tamamlandı: 0508_000423.txt
#
# Tamamlandı: 0508_000426.txt
#
# Tamamlandı: 0508_000429.txt
#
# Tamamlandı: 0508_000432.txt
#
# Tamamlandı: 0508_000435.txt
#
# Tamamlandı: 0508_000438.txt
#
# Tamamlandı: 0508_000441.txt
#
# Tamamlandı: 0508_000444.txt
#
# Tamamlandı: 0508_000447.txt
#
# Tamamlandı: 0508_000450.txt
#
# Tamamlandı: 0508_000453.txt
#
# Tamamlandı: 0508_000456.txt
#
# Tamamlandı: 0508_000459.txt
#
# Tamamlandı: 0508_000462.txt
#
# Tamamlandı: 0508_000465.txt
#
# Tamamlandı: 0508_000468.txt
#
# Tamamlandı: 0508_000471.txt
#
# Tamamlandı: 0508_000474.txt
#
# Tamamlandı: 0508_000477.txt
#
# Tamamlandı: 0508_000480.txt
#
# Tamamlandı: 0508_000483.txt
#
# Tamamlandı: 0508_000486.txt
#
# Tamamlandı: 0508_000489.txt
#
# Tamamlandı: 0508_000492.txt
#
# Tamamlandı: 0508_000495.txt
#
# Tamamlandı: 0508_000498.txt
#
# Tamamlandı: 0508_000501.txt
#
# Tamamlandı: 0508_000504.txt
#
# Tamamlandı: 0508_000507.txt
#
# Tamamlandı: 0508_000510.txt
#
# Tamamlandı: 0508_000513.txt
#
# Tamamlandı: 0508_000516.txt
#
# Tamamlandı: 0508_000519.txt
#
# Tamamlandı: 0508_000522.txt
#
# Tamamlandı: 0508_000525.txt
#
# Tamamlandı: 0508_000528.txt
#
# Tamamlandı: 0508_000531.txt
#
# Tamamlandı: 0508_000534.txt
#
# Tamamlandı: 0508_000537.txt
#
# Tamamlandı: 0508_000540.txt
#
# Tamamlandı: 0508_000543.txt
#
# Tamamlandı: 0508_000546.txt
#
# Tamamlandı: 0508_000549.txt
#
# Tamamlandı: 0508_000552.txt
#
# Tamamlandı: 0508_000555.txt
#
# Tamamlandı: 0508_000558.txt
#
# Tamamlandı: 0508_000561.txt
#
# Tamamlandı: 0508_000564.txt
#
# Tamamlandı: 0508_000567.txt
#
# Tamamlandı: 0508_000570.txt
#
# Tamamlandı: 0508_000573.txt
#
# Tamamlandı: 0508_000576.txt
#
# Tamamlandı: 0508_000579.txt
#
# Tamamlandı: 0508_000582.txt
#
# Tamamlandı: 0508_000585.txt
#
# Tamamlandı: 0508_000588.txt
#
# Tamamlandı: 0508_000591.txt
#
# Tamamlandı: 0508_000594.txt
#
# Tamamlandı: 0508_000597.txt
#
# Tamamlandı: 0508_000600.txt
#
# Tamamlandı: 0508_000603.txt
#
# Tamamlandı: 0508_000606.txt
#
# Tamamlandı: 0508_000609.txt
#
# Tamamlandı: 0508_000612.txt
#
# Tamamlandı: 0508_000615.txt
#
# Tamamlandı: 0508_000618.txt
#
# Tamamlandı: 0508_000621.txt
#
# Tamamlandı: 0508_000624.txt
#
# Tamamlandı: 0508_000627.txt
#
# Tamamlandı: 0508_000630.txt
#
# Tamamlandı: 0508_000633.txt
#
# Tamamlandı: 0508_000636.txt
#
# Tamamlandı: 0508_000639.txt
#
# Tamamlandı: 0508_000642.txt
#
# Tamamlandı: 0508_000645.txt
#
# Tamamlandı: 0508_000648.txt
#
# Tamamlandı: 0508_000651.txt
#
# Tamamlandı: 0508_000654.txt
#
# Tamamlandı: 0508_000657.txt
#
# Tamamlandı: 0508_000660.txt
#
# Tamamlandı: 0508_000663.txt
#
# Tamamlandı: 0508_000666.txt
#
# Tamamlandı: 0508_000669.txt
#
# Tamamlandı: 0508_000672.txt
#
# Tamamlandı: 0508_000675.txt
#
# Tamamlandı: 0508_000678.txt
#
# Tamamlandı: 0508_000681.txt
#
# Tamamlandı: 0508_000684.txt
#
# Tamamlandı: 0508_000687.txt
#
# Tamamlandı: 0508_000690.txt
#
# Tamamlandı: 0508_000693.txt
#
# Tamamlandı: 0508_000696.txt
#
# Tamamlandı: 0508_000699.txt
#
# Tamamlandı: 0508_000702.txt
#
# Tamamlandı: 0508_000705.txt
#
# Tamamlandı: 0508_000708.txt
#
# Tamamlandı: 0508_000711.txt
#
# Tamamlandı: 0508_000714.txt
#
# Tamamlandı: 0508_000717.txt
#
# Tamamlandı: 0508_000720.txt
#
# Tamamlandı: 0508_000723.txt
#
# Tamamlandı: 0508_000726.txt
#
# Tamamlandı: 0508_000729.txt
#
# Tamamlandı: 0508_000732.txt
#
# Tamamlandı: 0508_000735.txt
#
# Tamamlandı: 0508_000738.txt
#
# Tamamlandı: 0508_000741.txt
#
# Tamamlandı: 0508_000744.txt
#
# Tamamlandı: 0508_000747.txt
#
# Tamamlandı: 0508_000750.txt
#
# Tamamlandı: 0508_000753.txt
#
# Tamamlandı: 0508_000756.txt
#
# Tamamlandı: 0508_000759.txt
#
# Tamamlandı: 0508_000762.txt
#
# Tamamlandı: 0508_000765.txt
#
# Tamamlandı: 0508_000768.txt
#
# Tamamlandı: 0508_000771.txt
#
# Tamamlandı: 0508_000774.txt
#
# Tamamlandı: 0508_000777.txt
#
# Tamamlandı: 0508_000780.txt
#
# Tamamlandı: 0508_000783.txt
#
# Tamamlandı: 0508_000786.txt
#
# Tamamlandı: 0508_000789.txt
#
# Tamamlandı: 0508_000792.txt
#
# Tamamlandı: 0508_000795.txt
#
# Tamamlandı: 0508_000798.txt
#
# Tamamlandı: 0508_000801.txt
#
# Tamamlandı: 0508_000804.txt
#
# Tamamlandı: 0508_000807.txt
#
# Tamamlandı: 0508_000810.txt
#
# Tamamlandı: 0508_000813.txt
#
# Tamamlandı: 0508_000816.txt
#
# Tamamlandı: 0508_000819.txt
#
# Tamamlandı: 0508_000822.txt
#
# Tamamlandı: 0508_000825.txt
#
# Tamamlandı: 0508_000828.txt
#
# Tamamlandı: 0508_000831.txt
#
# Tamamlandı: 0508_000834.txt
#
# Tamamlandı: 0508_000837.txt
#
# Tamamlandı: 0508_000840.txt
#
# Tamamlandı: 0508_000843.txt
#
# Tamamlandı: 0508_000846.txt
#
# Tamamlandı: 0508_000849.txt
#
# Tamamlandı: 0508_000852.txt
#
# Tamamlandı: 0508_000855.txt
#
# Tamamlandı: 0508_000858.txt
#
# Tamamlandı: 0508_000861.txt
#
# Tamamlandı: 0508_000864.txt
#
# Tamamlandı: 0508_000867.txt
#
# Tamamlandı: 0508_000870.txt
#
# Tamamlandı: 0508_000873.txt
#
# Tamamlandı: 0508_000876.txt
#
# Tamamlandı: 0508_000879.txt
#
# Tamamlandı: 0508_000882.txt
#
# Tamamlandı: 0508_000885.txt
#
# Tamamlandı: 0508_000888.txt
#
# Tamamlandı: 0508_000891.txt
#
# Tamamlandı: 0508_000894.txt
#
# Tamamlandı: 0508_000897.txt
#
# Tamamlandı: 0508_000900.txt
#
# Tamamlandı: 0508_000903.txt
#
# Tamamlandı: 0508_000906.txt
#
# Tamamlandı: 0508_000909.txt
#
# Tamamlandı: 0508_000912.txt
#
# Tamamlandı: 0508_000915.txt
#
# Tamamlandı: 0508_000918.txt
#
# Tamamlandı: 0508_000921.txt
#
# Tamamlandı: 0508_000924.txt
#
# Tamamlandı: 0508_000927.txt
#
# Tamamlandı: 0508_000930.txt
#
# Tamamlandı: 0508_000933.txt
#
# Tamamlandı: 0508_000936.txt
#
# Tamamlandı: 0508_000939.txt
#
# Tamamlandı: 0508_000942.txt
#
# Tamamlandı: 0508_000945.txt
#
# Tamamlandı: 0508_000948.txt
#
# Tamamlandı: 0508_000951.txt
#
# Tamamlandı: 0508_000954.txt
#
# Tamamlandı: 0508_000957.txt
#
# Tamamlandı: 0508_000960.txt
#
# Tamamlandı: 0508_000963.txt
#
# Tamamlandı: 0508_000966.txt
#
# Tamamlandı: 0508_000969.txt
#
# Tamamlandı: 0508_000972.txt
#
# Tamamlandı: 0508_000975.txt
#
# Tamamlandı: 0508_000978.txt
#
# Tamamlandı: 0508_000981.txt
#
# Tamamlandı: 0508_000984.txt
#
# Tamamlandı: 0508_000987.txt
#
# Tamamlandı: 0508_000990.txt
#
# Tamamlandı: 0508_000993.txt
#
# Tamamlandı: 0508_000996.txt
#
# Tamamlandı: 0508_000999.txt
#
# Tamamlandı: 0508_001002.txt
#
# Tamamlandı: 0508_001005.txt
#
# Tamamlandı: 0508_001008.txt
#
# Tamamlandı: 0508_001011.txt
#
# Tamamlandı: 0508_001014.txt
#
# Tamamlandı: 0508_001017.txt
#
# Tamamlandı: 0508_001020.txt
#
# Tamamlandı: 0508_001023.txt
#
# Tamamlandı: 0508_001026.txt
#
# Tamamlandı: 0508_001029.txt
#
# Tamamlandı: 0508_001032.txt
#
# Tamamlandı: 0508_001035.txt
#
# Tamamlandı: 0508_001038.txt
#
# Tamamlandı: 0508_001041.txt
#
# Tamamlandı: 0508_001044.txt
#
# Tamamlandı: 0508_001047.txt
#
# Tamamlandı: 0508_001050.txt
#
# Tamamlandı: 0508_001053.txt
#
# Tamamlandı: 0508_001056.txt
#
# Tamamlandı: 0508_001059.txt
#
# Tamamlandı: 0508_001062.txt
#
# Tamamlandı: 0508_001065.txt
#
# Tamamlandı: 0508_001068.txt
#
# Tamamlandı: 0508_001071.txt
#
# Tamamlandı: 0508_001074.txt
#
# Tamamlandı: 0508_001077.txt
#
# Tamamlandı: 0508_001080.txt
#
# Tamamlandı: 0508_001083.txt
#
# Tamamlandı: 0508_001086.txt
#
# Tamamlandı: 0508_001089.txt
#
# Tamamlandı: 0508_001092.txt
#
# Tamamlandı: 0508_001095.txt
#
# Tamamlandı: 0508_001098.txt
#
# Tamamlandı: 0508_001101.txt
#
# Tamamlandı: 0508_001104.txt
#
# Tamamlandı: 0508_001107.txt
#
# Tamamlandı: 0508_001110.txt
#
# Tamamlandı: 0508_001113.txt
#
# Tamamlandı: 0508_001116.txt
#
# Tamamlandı: 0508_001119.txt
#
# Tamamlandı: 0508_001122.txt
#
# Tamamlandı: 0508_001125.txt
#
# Tamamlandı: 0508_001128.txt
#
# Tamamlandı: 0508_001131.txt
#
# Tamamlandı: 0508_001134.txt
#
# Tamamlandı: 0508_001137.txt
#
# Tamamlandı: 0508_001140.txt
#
# Tamamlandı: 0508_001143.txt
#
# Tamamlandı: 0508_001146.txt
#
# Tamamlandı: 0508_001149.txt
#
# Tamamlandı: 0508_001152.txt
#
# Tamamlandı: 0508_001155.txt
#
# Tamamlandı: 0508_001158.txt
#
# Tamamlandı: 0508_001161.txt
#
# Tamamlandı: 0508_001164.txt
#
# Tamamlandı: 0508_001167.txt
#
# Tamamlandı: 0508_001170.txt
#
# Tamamlandı: 0508_001173.txt
#
# Tamamlandı: 0508_001176.txt
#
# Tamamlandı: 0508_001179.txt
#
# Tamamlandı: 0508_001182.txt
#
# Tamamlandı: 0508_001185.txt
#
# Tamamlandı: 0508_001188.txt
#
# Tamamlandı: 0508_001191.txt
#
# Tamamlandı: 0508_001194.txt
#
# Tamamlandı: 0508_001197.txt
#
# Tamamlandı: 0508_001200.txt
#
# Tamamlandı: 0508_001203.txt
#
# Tamamlandı: 0508_001206.txt
#
# Tamamlandı: 0508_001209.txt
#
# Tamamlandı: 0508_001212.txt
#
# Tamamlandı: 0508_001215.txt
#
# Tamamlandı: 0508_001218.txt
#
# Tamamlandı: 0508_001221.txt
#
# Tamamlandı: 0508_001224.txt
#
# Tamamlandı: 0508_001227.txt
#
# Tamamlandı: 0508_001230.txt
#
# Tamamlandı: 0508_001233.txt
#
# Tamamlandı: 0508_001236.txt
#
# Tamamlandı: 0508_001239.txt
#
# Tamamlandı: 0508_001242.txt
#
# Tamamlandı: 0508_001245.txt
#
# Tamamlandı: 0508_001248.txt
#
# Tamamlandı: 0508_001251.txt
#
# Tamamlandı: 0508_001254.txt
#
# Tamamlandı: 0508_001257.txt
#
# Tamamlandı: 0508_001260.txt
#
# Tamamlandı: 0508_001263.txt
#
# Tamamlandı: 0508_001266.txt
#
# Tamamlandı: 0508_001269.txt
#
# Tamamlandı: 0508_001272.txt
#
# Tamamlandı: 0508_001275.txt
#
# Tamamlandı: 0508_001278.txt
#
# Tamamlandı: 0508_001281.txt
#
# Tamamlandı: 0508_001284.txt
#
# Tamamlandı: 0508_001287.txt
#
# Tamamlandı: 0508_001290.txt
#
# Tamamlandı: 0508_001293.txt
#
# Tamamlandı: 0508_001296.txt
#
# Tamamlandı: 0508_001299.txt
#
# Tamamlandı: 0508_001302.txt
#
# Tamamlandı: 0508_001305.txt
#
# Tamamlandı: 0508_001308.txt
#
# Tamamlandı: 0508_001311.txt
#
# Tamamlandı: 0508_001314.txt
#
# Tamamlandı: 0508_001317.txt
#
# Tamamlandı: 0508_001320.txt
#
# Tamamlandı: 0508_001323.txt
#
# Tamamlandı: 0508_001326.txt
#
# Tamamlandı: 0508_001329.txt
#
# Tamamlandı: 0508_001332.txt
#
# Tamamlandı: 0508_001335.txt
#
# Tamamlandı: 0508_001338.txt
#
# Tamamlandı: 0508_001341.txt
#
# Tamamlandı: 0508_001344.txt
#
# Tamamlandı: 0508_001347.txt
#
# Tamamlandı: 0508_001350.txt
#
# Tamamlandı: 0508_001353.txt
#
# Tamamlandı: 0508_001356.txt
#
# Tamamlandı: 0508_001359.txt
#
# Tamamlandı: 0508_001362.txt
#
# Tamamlandı: 0508_001365.txt
#
# Tamamlandı: 0508_001368.txt
#
# Tamamlandı: 0508_001371.txt
#
# [0508_001374.txt] Silinen: 3 0.710938 0.522222 0.141667 0.264815  (IoU=0.84)
# Tamamlandı: 0508_001374.txt
#
# Tamamlandı: 0508_001377.txt
#
# Tamamlandı: 0508_001380.txt
#
# Tamamlandı: 0508_001383.txt
#
# Tamamlandı: 0508_001386.txt
#
# Tamamlandı: 0508_001389.txt
#
# [0508_001392.txt] Silinen: 2 0.896354 0.452315 0.106250 0.263889  (IoU=0.98)
# Tamamlandı: 0508_001392.txt
#
# Tamamlandı: 0508_001395.txt
#
# Tamamlandı: 0508_001398.txt
#
# Tamamlandı: 0508_001401.txt
#
# Tamamlandı: 0508_001404.txt
#
# Tamamlandı: 0508_001407.txt
#
# Tamamlandı: 0508_001410.txt
#
# Tamamlandı: 0508_001413.txt
#
# Tamamlandı: 0508_001416.txt
#
# Tamamlandı: 0508_001419.txt
#
# Tamamlandı: 0508_001422.txt
#
# Tamamlandı: 0508_001425.txt
#
# Tamamlandı: 0508_001428.txt
#
# Tamamlandı: 0508_001431.txt
#
# Tamamlandı: 0508_001434.txt
#
# Tamamlandı: 0508_001437.txt
#
# Tamamlandı: 0508_001440.txt
#
# Tamamlandı: 0508_001443.txt
#
# Tamamlandı: 0508_001446.txt
#
# Tamamlandı: 0508_001449.txt
#
# Tamamlandı: 0508_001452.txt
#
# Tamamlandı: 0508_001455.txt
#
# Tamamlandı: 0508_001458.txt
#
# Tamamlandı: 0508_001461.txt
#
# Tamamlandı: 0508_001464.txt
#
# Tamamlandı: 0508_001467.txt
#
# Tamamlandı: 0508_001470.txt
#
# Tamamlandı: 0508_001473.txt
#
# Tamamlandı: 0508_001476.txt
#
# Tamamlandı: 0508_001479.txt
#
# Tamamlandı: 0508_001482.txt
#
# Tamamlandı: 0508_001485.txt
#
# Tamamlandı: 0508_001488.txt
#
# Tamamlandı: 0508_001491.txt
#
# Tamamlandı: 0508_001494.txt
#
# Tamamlandı: 0508_001497.txt
#
# Tamamlandı: 0508_001500.txt
#
# Tamamlandı: 0508_001503.txt
#
# Tamamlandı: 0508_001506.txt
#
# Tamamlandı: 0508_001509.txt
#
# Tamamlandı: 0508_001512.txt
#
# Tamamlandı: 0508_001515.txt
#
# Tamamlandı: 0508_001518.txt
#
# Tamamlandı: 0508_001521.txt
#
# Tamamlandı: 0508_001524.txt
#
# Tamamlandı: 0508_001527.txt
#
# Tamamlandı: 0508_001530.txt
#
# Tamamlandı: 0508_001533.txt
#
# Tamamlandı: 0508_001536.txt
#
# Tamamlandı: 0508_001539.txt
#
# Tamamlandı: 0508_001542.txt
#
# Tamamlandı: 0508_001545.txt
#
# Tamamlandı: 0508_001548.txt
#
# Tamamlandı: 0508_001551.txt
#
# Tamamlandı: 0508_001554.txt
#
# Tamamlandı: 0508_001557.txt
#
# Tamamlandı: 0508_001560.txt
#
# Tamamlandı: 0508_001563.txt
#
# Tamamlandı: 0508_001566.txt
#
# Tamamlandı: 0508_001569.txt
#
# Tamamlandı: 0508_001572.txt
#
# Tamamlandı: 0508_001575.txt
#
# Tamamlandı: 0508_001578.txt
#
# Tamamlandı: 0508_001581.txt
#
# Tamamlandı: 0508_001584.txt
#
# Tamamlandı: 0508_001587.txt
#
# Tamamlandı: 0508_001590.txt
#
# Tamamlandı: 0508_001593.txt
#
# Tamamlandı: 0508_001596.txt
#
# Tamamlandı: 0508_001599.txt
#
# Tamamlandı: 0508_001602.txt
#
# Tamamlandı: 0508_001605.txt
#
# Tamamlandı: 0508_001608.txt
#
# Tamamlandı: 0508_001611.txt
#
# Tamamlandı: 0508_001614.txt
#
# Tamamlandı: 0508_001617.txt
#
# Tamamlandı: 0508_001620.txt
#
# Tamamlandı: 0508_001623.txt
#
# Tamamlandı: 0508_001626.txt
#
# Tamamlandı: 0508_001629.txt
#
# Tamamlandı: 0508_001632.txt
#
# Tamamlandı: 0508_001635.txt
#
# Tamamlandı: 0508_001638.txt
#
# Tamamlandı: 0508_001641.txt
#
# Tamamlandı: 0508_001644.txt
#
# Tamamlandı: 0508_001647.txt
#
# Tamamlandı: 0508_001650.txt
#
# Tamamlandı: 0508_001653.txt
#
# Tamamlandı: 0508_001656.txt
#
# Tamamlandı: 0508_001659.txt
#
# Tamamlandı: 0508_001662.txt
#
# Tamamlandı: 0508_001665.txt
#
# Tamamlandı: 0508_001668.txt
#
# Tamamlandı: 0508_001671.txt
#
# Tamamlandı: 0508_001674.txt
#
# Tamamlandı: 0508_001677.txt
#
# Tamamlandı: 0508_001680.txt
#
# Tamamlandı: 0508_001683.txt
#
# Tamamlandı: 0508_001686.txt
#
# Tamamlandı: 0508_001689.txt
#
# Tamamlandı: 0508_001692.txt
#
# Tamamlandı: 0508_001695.txt
#
# Tamamlandı: 0508_001698.txt
#
# Tamamlandı: 0508_001701.txt
#
# Tamamlandı: 0508_001704.txt
#
# Tamamlandı: 0508_001707.txt
#
# Tamamlandı: 0508_001710.txt
#
# Tamamlandı: 0508_001713.txt
#
# Tamamlandı: 0508_001716.txt
#
# Tamamlandı: 0508_001719.txt
#
# Tamamlandı: 0508_001722.txt
#
# Tamamlandı: 0508_001725.txt
#
# Tamamlandı: 0508_001728.txt
#
# Tamamlandı: 0508_001731.txt
#
# Tamamlandı: 0508_001734.txt
#
# Tamamlandı: 0508_001737.txt
#
# Tamamlandı: 0508_001740.txt
#
# Tamamlandı: 0508_001743.txt
#
# Tamamlandı: 0508_001746.txt
#
# Tamamlandı: 0508_001749.txt
#
# Tamamlandı: 0508_001752.txt
#
# Tamamlandı: 0508_001755.txt
#
# Tamamlandı: 0508_001758.txt
#
# Tamamlandı: 0508_001761.txt
#
# Tamamlandı: 0508_001764.txt
#
# Tamamlandı: 0508_001767.txt
#
# Tamamlandı: 0508_001770.txt
#
# Tamamlandı: 0508_001773.txt
#
# Tamamlandı: 0508_001776.txt
#
# Tamamlandı: 0508_001779.txt
#
# Tamamlandı: 0508_001782.txt
#
# Tamamlandı: 0508_001785.txt
#
# Tamamlandı: 0508_001788.txt
#
# Tamamlandı: 0508_001791.txt
#
# Tamamlandı: 0508_001794.txt
#
# Tamamlandı: 0508_001797.txt
#
# Tamamlandı: 0508_001800.txt
#
# Tamamlandı: 0508_001803.txt
#
# Tamamlandı: 0508_001806.txt
#
# Tamamlandı: 0508_001809.txt
#
# Tamamlandı: 0508_001812.txt
#
# Tamamlandı: 0508_001815.txt
#
# Tamamlandı: 0508_001818.txt
#
# Tamamlandı: 0508_001821.txt
#
# Tamamlandı: 0508_001824.txt
#
# Tamamlandı: 0508_001827.txt
#
# Tamamlandı: 0508_001830.txt
#
# Tamamlandı: 0508_001833.txt
#
# Tamamlandı: 0508_001836.txt
#
# Tamamlandı: 0508_001839.txt
#
# Tamamlandı: 0508_001842.txt
#
# Tamamlandı: 0508_001845.txt
#
# Tamamlandı: 0508_001848.txt
#
# Tamamlandı: 0508_001851.txt
#
# Tamamlandı: 0508_001854.txt
#
# Tamamlandı: 0508_001857.txt
#
# Tamamlandı: 0508_001860.txt
#
# Tamamlandı: 0508_001863.txt
#
# Tamamlandı: 0508_001866.txt
#
# Tamamlandı: 0508_001869.txt
#
# Tamamlandı: 0508_001872.txt
#
# Tamamlandı: 0508_001875.txt
#
# Tamamlandı: 0508_001878.txt
#
# Tamamlandı: 0508_001881.txt
#
# Tamamlandı: 0508_001884.txt
#
# Tamamlandı: 0508_001887.txt
#
# Tamamlandı: 0508_001890.txt
#
# Tamamlandı: 0508_001893.txt
#
# Tamamlandı: 0508_001896.txt
#
# Tamamlandı: 0508_001899.txt
#
# Tamamlandı: 0508_001902.txt
#
# Tamamlandı: 0508_001905.txt
#
# Tamamlandı: 0508_001908.txt
#
# Tamamlandı: 0508_001911.txt
#
# Tamamlandı: 0508_001914.txt
#
# Tamamlandı: 0508_001917.txt
#
# Tamamlandı: 0508_001920.txt
#
# Tamamlandı: 0508_001923.txt
#
# Tamamlandı: 0508_001926.txt
#
# Tamamlandı: 0508_001929.txt
#
# Tamamlandı: 0508_001932.txt
#
# Tamamlandı: 0508_001935.txt
#
# Tamamlandı: 0508_001938.txt
#
# Tamamlandı: 0508_001941.txt
#
# Tamamlandı: 0508_001944.txt
#
# Tamamlandı: 0508_001947.txt
#
# Tamamlandı: 0508_001950.txt
#
# Tamamlandı: 0508_001953.txt
#
# Tamamlandı: 0508_001956.txt
#
# Tamamlandı: 0508_001959.txt
#
# Tamamlandı: 0508_001962.txt
#
# Tamamlandı: 0508_001965.txt
#
# Tamamlandı: 0508_001968.txt
#
# Tamamlandı: 0508_001971.txt
#
# Tamamlandı: 0508_001974.txt
#
# Tamamlandı: 0508_001977.txt
#
# Tamamlandı: 0508_001980.txt
#
# Tamamlandı: 0508_001983.txt
#
# Tamamlandı: 0508_001986.txt
#
# Tamamlandı: 0508_001989.txt
#
# Tamamlandı: 0508_001992.txt
#
# Tamamlandı: 0508_001995.txt
#
# Tamamlandı: 0508_001998.txt
#
# Tamamlandı: 0508_002001.txt
#
# Tamamlandı: 0508_002004.txt
#
# Tamamlandı: 0508_002007.txt
#
# Tamamlandı: 0508_002010.txt
#
# Tamamlandı: 0508_002013.txt
#
# Tamamlandı: 0508_002016.txt
#
# Tamamlandı: 0508_002019.txt
#
# Tamamlandı: 0508_002022.txt
#
# Tamamlandı: 0508_002025.txt
#
# Tamamlandı: 0508_002028.txt
#
# Tamamlandı: 0508_002031.txt
#
# Tamamlandı: 0508_002034.txt
#
# Tamamlandı: 0508_002037.txt
#
# Tamamlandı: 0508_002040.txt
#
# Tamamlandı: 0508_002043.txt
#
# Tamamlandı: 0508_002046.txt
#
# Tamamlandı: 0508_002049.txt
#
# Tamamlandı: 0508_002052.txt
#
# Tamamlandı: 0508_002055.txt
#
# Tamamlandı: 0508_002058.txt
#
# Tamamlandı: 0508_002061.txt
#
# Tamamlandı: 0508_002064.txt
#
# Tamamlandı: 0508_002067.txt
#
# Tamamlandı: 0508_002070.txt
#
# Tamamlandı: 0508_002073.txt
#
# Tamamlandı: 0508_002076.txt
#
# Tamamlandı: 0508_002079.txt
#
# Tamamlandı: 0508_002082.txt
#
# Tamamlandı: 0508_002085.txt
#
# Tamamlandı: 0508_002088.txt
#
# Tamamlandı: 0508_002091.txt
#
# Tamamlandı: 0508_002094.txt
#
# Tamamlandı: 0508_002097.txt
#
# [0508_002100.txt] Silinen: 3 0.663281 0.512500 0.151562 0.289815  (IoU=0.80)
# Tamamlandı: 0508_002100.txt
#
# Tamamlandı: 0508_002103.txt
#
# Tamamlandı: 0508_002106.txt
#
# Tamamlandı: 0508_002109.txt
#
# Tamamlandı: 0508_002112.txt
#
# Tamamlandı: 0508_002115.txt
#
# Tamamlandı: 0508_002118.txt
#
# Tamamlandı: 0508_002121.txt
#
# Tamamlandı: 0508_002124.txt
#
# Tamamlandı: 0508_002127.txt
#
# Tamamlandı: 0508_002130.txt
#
# Tamamlandı: 0508_002133.txt
#
# Tamamlandı: 0508_002136.txt
#
# Tamamlandı: 0508_002139.txt
#
# Tamamlandı: 0508_002142.txt
#
# Tamamlandı: 0508_002145.txt
#
# Tamamlandı: 0508_002148.txt
#
# Tamamlandı: 0508_002151.txt
#
# Tamamlandı: 0508_002154.txt
#
# Tamamlandı: 0508_002157.txt
#
# Tamamlandı: 0508_002160.txt
#
# Tamamlandı: 0508_002163.txt
#
# Tamamlandı: 0508_002166.txt
#
# Tamamlandı: 0508_002169.txt
#
# Tamamlandı: 0508_002172.txt
#
# Tamamlandı: 0508_002175.txt
#
# Tamamlandı: 0508_002178.txt
#
# Tamamlandı: 0508_002181.txt
#
# Tamamlandı: 0508_002184.txt
#
# Tamamlandı: 0508_002187.txt
#
# Tamamlandı: 0508_002190.txt
#
# Tamamlandı: 0508_002193.txt
#
# Tamamlandı: 0508_002196.txt
#
# Tamamlandı: 0508_002199.txt
#
# Tamamlandı: 0508_002202.txt
#
# Tamamlandı: 0508_002205.txt
#
# Tamamlandı: 0508_002208.txt
#
# Tamamlandı: 0508_002211.txt
#
# Tamamlandı: 0508_002214.txt
#
# Tamamlandı: 0508_002217.txt
#
# Tamamlandı: 0508_002220.txt
#
# Tamamlandı: 0508_002223.txt
#
# Tamamlandı: 0508_002226.txt
#
# Tamamlandı: 0508_002229.txt
#
# Tamamlandı: 0508_002232.txt
#
# Tamamlandı: 0508_002235.txt
#
# Tamamlandı: 0508_002238.txt
#
# Tamamlandı: 0508_002241.txt
#
# Tamamlandı: 0508_002244.txt
#
# Tamamlandı: 0508_002247.txt
#
# Tamamlandı: 0508_002250.txt
#
# Tamamlandı: 0508_002253.txt
#
# Tamamlandı: 0508_002256.txt
#
# Tamamlandı: 0508_002259.txt
#
# Tamamlandı: 0508_002262.txt
#
# Tamamlandı: 0508_002265.txt
#
# Tamamlandı: 0508_002268.txt
#
# Tamamlandı: 0508_002271.txt
#
# Tamamlandı: 0508_002274.txt
#
# Tamamlandı: 0508_002277.txt
#
# Tamamlandı: 0508_002280.txt
#
# Tamamlandı: 0508_002283.txt
#
# Tamamlandı: 0508_002286.txt
#
# Tamamlandı: 0508_002289.txt
#
# Tamamlandı: 0508_002292.txt
#
# Tamamlandı: 0508_002295.txt
#
# Tamamlandı: 0508_002298.txt
#
# Tamamlandı: 0508_002301.txt
#
# Tamamlandı: 0508_002304.txt
#
# Tamamlandı: 0508_002307.txt
#
# Tamamlandı: 0508_002310.txt
#
# Tamamlandı: 0508_002313.txt
#
# Tamamlandı: 0508_002316.txt
#
# Tamamlandı: 0508_002319.txt
#
# Tamamlandı: 0508_002322.txt
#
# Tamamlandı: 0508_002325.txt
#
# Tamamlandı: 0508_002328.txt
#
# Tamamlandı: 0508_002331.txt
#
# Tamamlandı: 0508_002334.txt
#
# Tamamlandı: 0508_002337.txt
#
# Tamamlandı: 0508_002340.txt
#
# Tamamlandı: 0508_002343.txt
#
# Tamamlandı: 0508_002346.txt
#
# Tamamlandı: 0508_002349.txt
#
# Tamamlandı: 0508_002352.txt
#
# Tamamlandı: 0508_002355.txt
#
# Tamamlandı: 0508_002358.txt
#
# [0508_002361.txt] Silinen: 1 0.505990 0.504630 0.146354 0.259259  (IoU=0.94)
# Tamamlandı: 0508_002361.txt
#
# Tamamlandı: 0508_002364.txt
#
# [0508_002367.txt] Silinen: 1 0.586458 0.503241 0.137500 0.262037  (IoU=0.94)
# Tamamlandı: 0508_002367.txt
#
# Tamamlandı: 0508_002370.txt
#
# Tamamlandı: 0508_002373.txt
#
# Tamamlandı: 0508_002376.txt
#
# Tamamlandı: 0508_002379.txt
#
# Tamamlandı: 0508_002382.txt
#
# Tamamlandı: 0508_002385.txt
#
# Tamamlandı: 0508_002388.txt
#
# Tamamlandı: 0508_002391.txt
#
# Tamamlandı: 0508_002394.txt
#
# Tamamlandı: 0508_002397.txt
#
# [0508_002400.txt] Silinen: 0 0.150260 0.485185 0.109896 0.200000  (IoU=0.99)
# Tamamlandı: 0508_002400.txt
#
# Tamamlandı: 0508_002403.txt
#
# [0508_002406.txt] Silinen: 1 0.205208 0.508333 0.121875 0.216667  (IoU=0.95)
# Tamamlandı: 0508_002406.txt
#
# Tamamlandı: 0508_002409.txt
#
# Tamamlandı: 0508_002412.txt
#
# Tamamlandı: 0508_002415.txt
#
# Tamamlandı: 0508_002418.txt
#
# Tamamlandı: 0508_002421.txt
#
# Tamamlandı: 0508_002424.txt
#
# Tamamlandı: 0508_002427.txt
#
# Tamamlandı: 0508_002430.txt
#
# Tamamlandı: 0508_002433.txt
#
# Tamamlandı: 0508_002436.txt
#
# Tamamlandı: 0508_002439.txt
#
# Tamamlandı: 0508_002442.txt
#
# Tamamlandı: 0508_002445.txt
#
# Tamamlandı: 0508_002448.txt
#
# Tamamlandı: 0508_002451.txt
#
# Tamamlandı: 0508_002454.txt
#
# Tamamlandı: 0508_002457.txt
#
# Tamamlandı: 0508_002460.txt
#
# Tamamlandı: 0508_002463.txt
#
# Tamamlandı: 0508_002466.txt
#
# Tamamlandı: 0508_002469.txt
#
# Tamamlandı: 0508_002472.txt
#
# Tamamlandı: 0508_002475.txt
#
# Tamamlandı: 0508_002478.txt
#
# Tamamlandı: 0508_002481.txt
#
# Tamamlandı: 0508_002484.txt
#
# Tamamlandı: 0508_002487.txt
#
# Tamamlandı: 0508_002490.txt
#
# Tamamlandı: 0508_002493.txt
#
# Tamamlandı: 0508_002496.txt
#
# Tamamlandı: 0508_002499.txt
#
# Tamamlandı: 0508_002502.txt
#
# Tamamlandı: 0508_002505.txt
#
# Tamamlandı: 0508_002508.txt
#
# Tamamlandı: 0508_002511.txt
#
# Tamamlandı: 0508_002514.txt
#
# Tamamlandı: 0508_002517.txt
#
# Tamamlandı: 0508_002520.txt
#
# Tamamlandı: 0508_002523.txt
#
# Tamamlandı: 0508_002526.txt
#
# Tamamlandı: 0508_002529.txt
#
# Tamamlandı: 0508_002532.txt
#
# Tamamlandı: 0508_002535.txt
#
# Tamamlandı: 0508_002538.txt
#
# Tamamlandı: 0508_002541.txt
#
# Tamamlandı: 0508_002544.txt
#
# Tamamlandı: 0508_002547.txt
#
# Tamamlandı: 0508_002550.txt
#
# Tamamlandı: 0508_002553.txt
#
# Tamamlandı: 0508_002556.txt
#
# Tamamlandı: 0508_002559.txt
#
# Tamamlandı: 0508_002562.txt
#
# Tamamlandı: 0508_002565.txt
#
# Tamamlandı: 0508_002568.txt
#
# Tamamlandı: 0508_002571.txt
#
# Tamamlandı: 0508_002574.txt
#
# Tamamlandı: 0508_002577.txt
#
# Tamamlandı: 0508_002580.txt
#
# Tamamlandı: 0508_002583.txt
#
# Tamamlandı: 0508_002586.txt
#
# Tamamlandı: 0508_002589.txt
#
# Tamamlandı: 0508_002592.txt
#
# Tamamlandı: 0508_002595.txt
#
# Tamamlandı: 0508_002598.txt
#
# Tamamlandı: 0508_002601.txt
#
# Tamamlandı: 0508_002604.txt
#
# Tamamlandı: 0508_002607.txt
#
# Tamamlandı: 0508_002610.txt
#
# Tamamlandı: 0508_002613.txt
#
# Tamamlandı: 0508_002616.txt
#
# Tamamlandı: 0508_002619.txt
#
# Tamamlandı: 0508_002622.txt
#
# Tamamlandı: 0508_002625.txt
#
# Tamamlandı: 0508_002628.txt
#
# Tamamlandı: 0508_002631.txt
#
# Tamamlandı: 0508_002634.txt
#
# Tamamlandı: 0508_002637.txt
#
# Tamamlandı: 0508_002640.txt
#
# Tamamlandı: 0508_002643.txt
#
# Tamamlandı: 0508_002646.txt
#
# Tamamlandı: 0508_002649.txt
#
# Tamamlandı: 0508_002652.txt
#
# Tamamlandı: 0508_002655.txt
#
# Tamamlandı: 0508_002658.txt
#
# Tamamlandı: 0508_002661.txt
#
# Tamamlandı: 0508_002664.txt
#
# Tamamlandı: 0508_002667.txt
#
# Tamamlandı: 0508_002670.txt
#
# Tamamlandı: 0508_002673.txt
#
# Tamamlandı: 0508_002676.txt
#
# Tamamlandı: 0508_002679.txt
#
# Tamamlandı: 0508_002682.txt
#
# Tamamlandı: 0508_002685.txt
#
# Tamamlandı: 0508_002688.txt
#
# Tamamlandı: 0508_002691.txt
#
# Tamamlandı: 0508_002694.txt
#
# Tamamlandı: 0508_002697.txt
#
# Tamamlandı: 0508_002700.txt
#
# Tamamlandı: 0508_002703.txt
#
# Tamamlandı: 0508_002706.txt
#
# Tamamlandı: 0508_002709.txt
#
# Tamamlandı: 0508_002712.txt
#
# Tamamlandı: 0508_002715.txt
#
# Tamamlandı: 0508_002718.txt
#
# Tamamlandı: 0508_002721.txt
#
# Tamamlandı: 0508_002724.txt
#
# Tamamlandı: 0508_002727.txt
#
# Tamamlandı: 0508_002730.txt
#
# Tamamlandı: 0508_002733.txt
#
# Tamamlandı: 0508_002736.txt
#
# Tamamlandı: 0508_002739.txt
#
# Tamamlandı: 0508_002742.txt
#
# Tamamlandı: 0508_002745.txt
#
# Tamamlandı: 0508_002748.txt
#
# Tamamlandı: 0508_002751.txt
#
# Tamamlandı: 0508_002754.txt
#
# Tamamlandı: 0508_002757.txt
#
# Tamamlandı: 0508_002760.txt
#
# Tamamlandı: 0508_002763.txt
#
# Tamamlandı: 0508_002766.txt
#
# Tamamlandı: 0508_002769.txt
#
# Tamamlandı: 0508_002772.txt
#
# Tamamlandı: 0508_002775.txt
#
# Tamamlandı: 0508_002778.txt
#
# Tamamlandı: 0508_002781.txt
#
# Tamamlandı: 0508_002784.txt
#
# Tamamlandı: 0508_002787.txt
#
# Tamamlandı: 0508_002790.txt
#
# Tamamlandı: 0508_002793.txt
#
# Tamamlandı: 0508_002796.txt
#
# Tamamlandı: 0508_002799.txt
#
# Tamamlandı: 0508_002802.txt
#
# Tamamlandı: 0508_002805.txt
#
# Tamamlandı: 0508_002808.txt
#
# Tamamlandı: 0508_002811.txt
#
# Tamamlandı: 0508_002814.txt
#
# Tamamlandı: 0508_002817.txt
#
# Tamamlandı: 0508_002820.txt
#
# Tamamlandı: 0508_002823.txt
#
# Tamamlandı: 0508_002826.txt
#
# Tamamlandı: 0508_002829.txt
#
# Tamamlandı: 0508_002832.txt
#
# Tamamlandı: 0508_002835.txt
#
# Tamamlandı: 0508_002838.txt
#
# Tamamlandı: 0508_002841.txt
#
# Tamamlandı: 0508_002844.txt
#
# Tamamlandı: 0508_002847.txt
#
# Tamamlandı: 0508_002850.txt
#
# Tamamlandı: 0508_002853.txt
#
# Tamamlandı: 0508_002856.txt
#
# Tamamlandı: 0508_002859.txt
#
# Tamamlandı: 0508_002862.txt
#
# Tamamlandı: 0508_002865.txt
#
# Tamamlandı: 0508_002868.txt
#
# Tamamlandı: 0508_002871.txt
#
# Tamamlandı: 0508_002874.txt
#
# Tamamlandı: 0508_002877.txt
#
# Tamamlandı: 0508_002880.txt
#
# Tamamlandı: 0508_002883.txt
#
# Tamamlandı: 0508_002886.txt
#
# Tamamlandı: 0508_002889.txt
#
# Tamamlandı: 0508_002892.txt
#
# Tamamlandı: 0508_002895.txt
#
# Tamamlandı: 0508_002898.txt
#
# Tamamlandı: 0508_002901.txt
#
# Tamamlandı: 0508_002904.txt
#
# Tamamlandı: 0508_002907.txt
#
# Tamamlandı: 0508_002910.txt
#
# Tamamlandı: 0508_002913.txt
#
# Tamamlandı: 0508_002916.txt
#
# Tamamlandı: 0508_002919.txt
#
# Tamamlandı: 0508_002922.txt
#
# Tamamlandı: 0508_002925.txt
#
# Tamamlandı: 0508_002928.txt
#
# Tamamlandı: 0508_002931.txt
#
# Tamamlandı: 0508_002934.txt
#
# Tamamlandı: 0508_002937.txt
#
# Tamamlandı: 0508_002940.txt
#
# Tamamlandı: 0508_002943.txt
#
# Tamamlandı: 0508_002946.txt
#
# Tamamlandı: 0508_002949.txt
#
# Tamamlandı: 0508_002952.txt
#
# Tamamlandı: 0508_002955.txt
#
# Tamamlandı: 0508_002958.txt
#
# Tamamlandı: 0508_002961.txt
#
# Tamamlandı: 0508_002964.txt
#
# Tamamlandı: 0508_002967.txt
#
# Tamamlandı: 0508_002970.txt
#
# Tamamlandı: 0508_002973.txt
#
# Tamamlandı: 0508_002976.txt
#
# Tamamlandı: 0508_002979.txt
#
# Tamamlandı: 0508_002982.txt
#
# Tamamlandı: 0508_002985.txt
#
# Tamamlandı: 0508_002988.txt
#
# Tamamlandı: 0508_002991.txt
#
# Tamamlandı: 0508_002994.txt
#
# Tamamlandı: 0508_002997.txt
#
# Tamamlandı: 0508_003000.txt
#
# Tamamlandı: 0508_003003.txt
#
# Tamamlandı: 0508_003006.txt
#
# Tamamlandı: 0508_003009.txt
#
# Tamamlandı: 0508_003012.txt
#
# Tamamlandı: 0508_003015.txt
#
# Tamamlandı: 0508_003018.txt
#
# Tamamlandı: 0508_003021.txt
#
# Tamamlandı: 0508_003024.txt
#
# Tamamlandı: 0508_003027.txt
#
# Tamamlandı: 0508_003030.txt
#
# Tamamlandı: 0508_003033.txt
#
# Tamamlandı: 0508_003036.txt
#
# Tamamlandı: 0508_003039.txt
#
# Tamamlandı: 0508_003042.txt
#
# Tamamlandı: 0508_003045.txt
#
# Tamamlandı: 0508_003048.txt
#
# Tamamlandı: 0508_003051.txt
#
# Tamamlandı: 0508_003054.txt
#
# Tamamlandı: 0508_003057.txt
#
# Tamamlandı: 0508_003060.txt
#
# Tamamlandı: 0508_003063.txt
#
# Tamamlandı: 0508_003066.txt
#
# Tamamlandı: 0508_003069.txt
#
# Tamamlandı: 0508_003072.txt
#
# Tamamlandı: 0508_003075.txt
#
# Tamamlandı: 0508_003078.txt
#
# Tamamlandı: 0508_003081.txt
#
# Tamamlandı: 0508_003084.txt
#
# Tamamlandı: 0508_003087.txt
#
# Tamamlandı: 0508_003090.txt
#
# Tamamlandı: 0508_003093.txt
#
# Tamamlandı: 0508_003096.txt
#
# Tamamlandı: 0508_003099.txt
#
# Tamamlandı: 0508_003102.txt
#
# Tamamlandı: 0508_003105.txt
#
# Tamamlandı: 0508_003108.txt
#
# Tamamlandı: 0508_003111.txt
#
# Tamamlandı: 0508_003114.txt
#
# Tamamlandı: 0508_003117.txt
#
# Tamamlandı: 0508_003120.txt
#
# Tamamlandı: 0508_003123.txt
#
# Tamamlandı: 0508_003126.txt
#
# Tamamlandı: 0508_003129.txt
#
# Tamamlandı: 0508_003132.txt
#
# Tamamlandı: 0508_003135.txt
#
# Tamamlandı: 0508_003138.txt
#
# Tamamlandı: 0508_003141.txt
#
# Tamamlandı: 0508_003144.txt
#
# [0508_003147.txt] Silinen: 0 0.090625 0.442130 0.100000 0.223148  (IoU=0.93)
# Tamamlandı: 0508_003147.txt
#
# Tamamlandı: 0508_003150.txt
#
# Tamamlandı: 0508_003153.txt
#
# Tamamlandı: 0508_003156.txt
#
# Tamamlandı: 0508_003159.txt
#
# Tamamlandı: 0508_003162.txt
#
# Tamamlandı: 0508_003165.txt
#
# Tamamlandı: 0508_003168.txt
#
# Tamamlandı: 0508_003171.txt
#
# Tamamlandı: 0508_003174.txt
#
# Tamamlandı: 0508_003177.txt
#
# Tamamlandı: 0508_003180.txt
#
# Tamamlandı: 0508_003183.txt
#
# Tamamlandı: 0508_003186.txt
#
# Tamamlandı: 0508_003189.txt
#
# Tamamlandı: 0508_003192.txt
#
# Tamamlandı: 0508_003195.txt
#
# Tamamlandı: 0508_003198.txt
#
# Tamamlandı: 0508_003201.txt
#
# Tamamlandı: 0508_003204.txt
#
# Tamamlandı: 0508_003207.txt
#
# Tamamlandı: 0508_003210.txt
#
# Tamamlandı: 0508_003213.txt
#
# Tamamlandı: 0508_003216.txt
#
# Tamamlandı: 0508_003219.txt
#
# Tamamlandı: 0508_003222.txt
#
# Tamamlandı: 0508_003225.txt
#
# Tamamlandı: 0508_003228.txt
#
# Tamamlandı: 0508_003231.txt
#
# Tamamlandı: 0508_003234.txt
#
# Tamamlandı: 0508_003237.txt
#
# Tamamlandı: 0508_003240.txt
#
# Tamamlandı: 0508_003243.txt
#
# Tamamlandı: 0508_003246.txt
#
# Tamamlandı: 0508_003249.txt
#
# Tamamlandı: 0508_003252.txt
#
# Tamamlandı: 0508_003255.txt
#
# Tamamlandı: 0508_003258.txt
#
# Tamamlandı: 0508_003261.txt
#
# Tamamlandı: 0508_003264.txt
#
# Tamamlandı: 0508_003267.txt
#
# Tamamlandı: 0508_003270.txt
#
# Tamamlandı: 0508_003273.txt
#
# Tamamlandı: 0508_003276.txt
#
# Tamamlandı: 0508_003279.txt
#
# Tamamlandı: 0508_003282.txt
#
# Tamamlandı: 0508_003285.txt
#
# Tamamlandı: 0508_003288.txt
#
# Tamamlandı: 0508_003291.txt
#
# Tamamlandı: 0508_003294.txt
#
# Tamamlandı: 0508_003297.txt
#
# Tamamlandı: 0508_003300.txt
#
# Tamamlandı: 0508_003303.txt
#
# Tamamlandı: 0508_003306.txt
#
# Tamamlandı: 0508_003309.txt
#
# Tamamlandı: 0508_003312.txt
#
# Tamamlandı: 0508_003315.txt
#
# Tamamlandı: 0508_003318.txt
#
# Tamamlandı: 0508_003321.txt
#
# Tamamlandı: 0508_003324.txt
#
# Tamamlandı: 0508_003327.txt
#
# Tamamlandı: 0508_003330.txt
#
# Tamamlandı: 0508_003333.txt
#
# Tamamlandı: 0508_003336.txt
#
# Tamamlandı: 0508_003339.txt
#
# Tamamlandı: 0508_003342.txt
#
# Tamamlandı: 0508_003345.txt
#
# Tamamlandı: 0508_003348.txt
#
# Tamamlandı: 0508_003351.txt
#
# Tamamlandı: 0508_003354.txt
#
# Tamamlandı: 0508_003357.txt
#
# Tamamlandı: 0508_003360.txt
#
# Tamamlandı: 0508_003363.txt
#
# Tamamlandı: 0508_003366.txt
#
# Tamamlandı: 0508_003369.txt
#
# Tamamlandı: 0508_003372.txt
#
# Tamamlandı: 0508_003375.txt
#
# Tamamlandı: 0508_003378.txt
#
# Tamamlandı: 0508_003381.txt
#
# Tamamlandı: 0508_003384.txt
#
# Tamamlandı: 0508_003387.txt
#
# Tamamlandı: 0508_003390.txt
#
# Tamamlandı: 0508_003393.txt
#
# Tamamlandı: 0508_003396.txt
#
# Tamamlandı: 0508_003399.txt
#
# Tamamlandı: 0508_003402.txt
#
# Tamamlandı: 0508_003405.txt
#
# Tamamlandı: 0508_003408.txt
#
# Tamamlandı: 0508_003411.txt
#
# Tamamlandı: 0508_003414.txt
#
# Tamamlandı: 0508_003417.txt
#
# Tamamlandı: 0508_003420.txt
#
# Tamamlandı: 0508_003423.txt
#
# Tamamlandı: 0508_003426.txt
#
# Tamamlandı: 0508_003429.txt
#
# Tamamlandı: 0508_003432.txt
#
# Tamamlandı: 0508_003435.txt
#
# Tamamlandı: 0508_003438.txt
#
# Tamamlandı: 0508_003441.txt
#
# Tamamlandı: 0508_003444.txt
#
# Tamamlandı: 0508_003447.txt
#
# Tamamlandı: 0508_003450.txt
#
# Tamamlandı: 0508_003453.txt
#
# Tamamlandı: 0508_003456.txt
#
# Tamamlandı: 0508_003459.txt
#
# Tamamlandı: 0508_003462.txt
#
# Tamamlandı: 0508_003465.txt
#
# Tamamlandı: 0508_003468.txt
#
# Tamamlandı: 0508_003471.txt
#
# Tamamlandı: 0508_003474.txt
#
# Tamamlandı: 0508_003477.txt
#
# Tamamlandı: 0508_003480.txt
#
# Tamamlandı: 0508_003483.txt
#
# Tamamlandı: 0508_003486.txt
#
# Tamamlandı: 0508_003489.txt
#
# Tamamlandı: 0508_003492.txt
#
# Tamamlandı: 0508_003495.txt
#
# Tamamlandı: 0508_003498.txt
#
# Tamamlandı: 0508_003501.txt
#
# Tamamlandı: 0508_003504.txt
#
# Tamamlandı: 0508_003507.txt
#
# Tamamlandı: 0508_003510.txt
#
# Tamamlandı: 0508_003513.txt
#
# Tamamlandı: 0508_003516.txt
#
# Tamamlandı: 0508_003519.txt
#
# Tamamlandı: 0508_003522.txt
#
# Tamamlandı: 0508_003525.txt
#
# Tamamlandı: 0508_003528.txt
#
# Tamamlandı: 0508_003531.txt
#
# [0508_003534.txt] Silinen: 0 0.445052 0.558333 0.120313 0.227778  (IoU=0.98)
# Tamamlandı: 0508_003534.txt
#
# Tamamlandı: 0508_003537.txt
#
# [0508_003540.txt] Silinen: 0 0.522917 0.562963 0.126042 0.233333  (IoU=0.97)
# Tamamlandı: 0508_003540.txt
#
# Tamamlandı: 0508_003543.txt
#
# Tamamlandı: 0508_003546.txt
#
# Tamamlandı: 0508_003549.txt
#
# Tamamlandı: 0508_003552.txt
#
# Tamamlandı: 0508_003555.txt
#
# Tamamlandı: 0508_003558.txt
#
# Tamamlandı: 0508_003561.txt
#
# Tamamlandı: 0508_003564.txt
#
# Tamamlandı: 0508_003567.txt
#
# Tamamlandı: 0508_003570.txt
#
# Tamamlandı: 0508_003573.txt
#
# Tamamlandı: 0508_003576.txt
#
# Tamamlandı: 0508_003579.txt
#
# [0508_003582.txt] Silinen: 0 0.969271 0.418981 0.061458 0.204630  (IoU=0.97)
# Tamamlandı: 0508_003582.txt
#
# Tamamlandı: 0508_003585.txt
#
# Tamamlandı: 0508_003588.txt
#
# Tamamlandı: 0508_003591.txt
#
# Tamamlandı: 0508_003594.txt
#
# Tamamlandı: 0508_003597.txt
#
# Tamamlandı: 0508_003600.txt
#
# Tamamlandı: 0508_003603.txt
#
# Tamamlandı: 0508_003606.txt
#
# Tamamlandı: 0508_003609.txt
#
# Tamamlandı: 0508_003612.txt
#
# Tamamlandı: 0508_003615.txt
#
# Tamamlandı: 0508_003618.txt
#
# Tamamlandı: 0508_003621.txt
#
# Tamamlandı: 0508_003624.txt
#
# Tamamlandı: 0508_003627.txt
#
# Tamamlandı: 0508_003630.txt
#
# Tamamlandı: 0508_003633.txt
#
# Tamamlandı: 0508_003636.txt
#
# Tamamlandı: 0508_003639.txt
#
# Tamamlandı: 0508_003642.txt
#
# Tamamlandı: 0508_003645.txt
#
# Tamamlandı: 0508_003648.txt
#
# Tamamlandı: 0508_003651.txt
#
# Tamamlandı: 0508_003654.txt
#
# Tamamlandı: 0508_003657.txt
#
# Tamamlandı: 0508_003660.txt
#
# Tamamlandı: 0508_003663.txt
#
# Tamamlandı: 0508_003666.txt
#
# Tamamlandı: 0508_003669.txt
#
# Tamamlandı: 0508_003672.txt
#
# Tamamlandı: 0508_003675.txt
#
# Tamamlandı: 0508_003678.txt
#
# Tamamlandı: 0508_003681.txt
#
# Tamamlandı: 0508_003684.txt
#
# Tamamlandı: 0508_003687.txt
#
# Tamamlandı: 0508_003690.txt
#
# Tamamlandı: 0508_003693.txt
#
# Tamamlandı: 0508_003696.txt
#
# Tamamlandı: 0508_003699.txt
#
# Tamamlandı: 0508_003702.txt
#
# Tamamlandı: 0508_003705.txt
#
# Tamamlandı: 0508_003708.txt
#
# Tamamlandı: 0508_003711.txt
#
# Tamamlandı: 0508_003714.txt
#
# Tamamlandı: 0508_003717.txt
#
# Tamamlandı: 0508_003720.txt
#
# Tamamlandı: 0508_003723.txt
#
# Tamamlandı: 0508_003726.txt
#
# Tamamlandı: 0508_003729.txt
#
# Tamamlandı: 0508_003732.txt
#
# Tamamlandı: 0508_003735.txt
#
# Tamamlandı: 0508_003738.txt
#
# Tamamlandı: 0508_003741.txt
#
# Tamamlandı: 0508_003744.txt
#
# Tamamlandı: 0508_003747.txt
#
# Tamamlandı: 0508_003750.txt
#
# Tamamlandı: 0508_003753.txt
#
# Tamamlandı: 0508_003756.txt
#
# Tamamlandı: 0508_003759.txt
#
# Tamamlandı: 0508_003762.txt
#
# Tamamlandı: 0508_003765.txt
#
# Tamamlandı: 0508_003768.txt
#
# Tamamlandı: 0508_003771.txt
#
# Tamamlandı: 0508_003774.txt
#
# Tamamlandı: 0508_003777.txt
#
# Tamamlandı: 0508_003780.txt
#
# Tamamlandı: 0508_003783.txt
#
# Tamamlandı: 0508_003786.txt
#
# Tamamlandı: 0508_003789.txt
#
# Tamamlandı: 0508_003792.txt
#
# Tamamlandı: 0508_003795.txt
#
# Tamamlandı: 0508_003798.txt
#
# Tamamlandı: 0508_003801.txt
#
# Tamamlandı: 0508_003804.txt
#
# Tamamlandı: 0508_003807.txt
#
# Tamamlandı: 0508_003810.txt
#
# Tamamlandı: 0508_003813.txt
#
# Tamamlandı: 0508_003816.txt
#
# Tamamlandı: 0508_003819.txt
#
# Tamamlandı: 0508_003822.txt
#
# Tamamlandı: 0508_003825.txt
#
# Tamamlandı: 0508_003828.txt
#
# Tamamlandı: 0508_003831.txt
#
# Tamamlandı: 0508_003834.txt
#
# Tamamlandı: 0508_003837.txt
#
# Tamamlandı: 0508_003840.txt
#
# Tamamlandı: 0508_003843.txt
#
# Tamamlandı: 0508_003846.txt
#
# Tamamlandı: 0508_003849.txt
#
# Tamamlandı: 0508_003852.txt
#
# Tamamlandı: 0508_003855.txt
#
# Tamamlandı: 0508_003858.txt
#
# Tamamlandı: 0508_003861.txt
#
# Tamamlandı: 0508_003864.txt
#
# Tamamlandı: 0508_003867.txt
#
# Tamamlandı: 0508_003870.txt
#
# Tamamlandı: 0508_003873.txt
#
# Tamamlandı: 0508_003876.txt
#
# Tamamlandı: 0508_003879.txt
#
# Tamamlandı: 0508_003882.txt
#
# Tamamlandı: 0508_003885.txt
#
# Tamamlandı: 0508_003888.txt
#
# Tamamlandı: 0508_003891.txt
#
# Tamamlandı: 0508_003894.txt
#
# Tamamlandı: 0508_003897.txt
#
# Tamamlandı: 0508_003900.txt
#
# Tamamlandı: 0508_003903.txt
#
# Tamamlandı: 0508_003906.txt
#
# Tamamlandı: 0508_003909.txt
#
# Tamamlandı: 0508_003912.txt
#
# Tamamlandı: 0508_003915.txt
#
# Tamamlandı: 0508_003918.txt
#
# Tamamlandı: 0508_003921.txt
#
# Tamamlandı: 0508_003924.txt
#
# Tamamlandı: 0508_003927.txt
#
# Tamamlandı: 0508_003930.txt
#
# Tamamlandı: 0508_003933.txt
#
# Tamamlandı: 0508_003936.txt
#
# Tamamlandı: 0508_003939.txt
#
# Tamamlandı: 0508_003942.txt
#
# Tamamlandı: 0508_003945.txt
#
# Tamamlandı: 0508_003948.txt
#
# Tamamlandı: 0508_003951.txt
#
# Tamamlandı: 0508_003954.txt
#
# Tamamlandı: 0508_003957.txt
#
# Tamamlandı: 0508_003960.txt
#
# Tamamlandı: 0508_003963.txt
#
# Tamamlandı: 0508_003966.txt
#
# Tamamlandı: 0508_003969.txt
#
# Tamamlandı: 0508_003972.txt
#
# Tamamlandı: 0508_003975.txt
#
# Tamamlandı: 0508_003978.txt
#
# Tamamlandı: 0508_003981.txt
#
# Tamamlandı: 0508_003984.txt
#
# Tamamlandı: 0508_003987.txt
#
# Tamamlandı: 0508_003990.txt
#
# Tamamlandı: 0508_003993.txt
#
# Tamamlandı: 0508_003996.txt
#
# Tamamlandı: 0508_003999.txt
#
# Tamamlandı: 0508_004002.txt
#
# Tamamlandı: 0508_004005.txt
#
# Tamamlandı: 0508_004008.txt
#
# Tamamlandı: 0508_004011.txt
#
# Tamamlandı: 0508_004014.txt
#
# Tamamlandı: 0508_004017.txt
#
# Tamamlandı: 0508_004020.txt
#
# Tamamlandı: 0508_004023.txt
#
# Tamamlandı: 0508_004026.txt
#
# Tamamlandı: 0508_004029.txt
#
# Tamamlandı: 0508_004032.txt
#
# Tamamlandı: 0508_004035.txt
#
# Tamamlandı: 0508_004038.txt
#
# Tamamlandı: 0508_004041.txt
#
# Tamamlandı: 0508_004044.txt
#
# Tamamlandı: 0508_004047.txt
#
# Tamamlandı: 0508_004050.txt
#
# Tamamlandı: 0508_004053.txt
#
# Tamamlandı: 0508_004056.txt
#
# Tamamlandı: 0508_004059.txt
#
# Tamamlandı: 0508_004062.txt
#
# Tamamlandı: 0508_004065.txt
#
# Tamamlandı: 0508_004068.txt
#
# Tamamlandı: 0508_004071.txt
#
# Tamamlandı: 0508_004074.txt
#
# Tamamlandı: 0508_004077.txt
#
# Tamamlandı: 0508_004080.txt
#
# Tamamlandı: 0508_004083.txt
#
# Tamamlandı: 0508_004086.txt
#
# Tamamlandı: 0508_004089.txt
#
# Tamamlandı: 0508_004092.txt
#
# Tamamlandı: 0508_004095.txt
#
# Tamamlandı: 0508_004098.txt
#
# Tamamlandı: 0508_004101.txt
#
# Tamamlandı: 0508_004104.txt
#
# Tamamlandı: 0508_004107.txt
#
# Tamamlandı: 0508_004110.txt
#
# Tamamlandı: 0508_004113.txt
#
# Tamamlandı: 0508_004116.txt
#
# Tamamlandı: 0508_004119.txt
#
# Tamamlandı: 0508_004122.txt
#
# Tamamlandı: 0508_004125.txt
#
# Tamamlandı: 0508_004128.txt
#
# Tamamlandı: 0508_004131.txt
#
# Tamamlandı: 0508_004134.txt
#
# Tamamlandı: 0508_004137.txt
#
# Tamamlandı: 0508_004140.txt
#
# Tamamlandı: 0508_004143.txt
#
# Tamamlandı: 0508_004146.txt
#
# Tamamlandı: 0508_004149.txt
#
# Tamamlandı: 0508_004152.txt
#
# Tamamlandı: 0508_004155.txt
#
# Tamamlandı: 0508_004158.txt
#
# Tamamlandı: 0508_004161.txt
#
# Tamamlandı: 0508_004164.txt
#
# Tamamlandı: 0508_004167.txt
#
# Tamamlandı: 0508_004170.txt
#
# Tamamlandı: 0508_004173.txt
#
# Tamamlandı: 0508_004176.txt
#
# Tamamlandı: 0508_004179.txt
#
# Tamamlandı: 0508_004182.txt
#
# Tamamlandı: 0508_004185.txt
#
# Tamamlandı: 0508_004188.txt
#
# Tamamlandı: 0508_004191.txt
#
# Tamamlandı: 0508_004194.txt
#
# Tamamlandı: 0508_004197.txt
#
# Tamamlandı: 0508_004200.txt
#
# Tamamlandı: 0508_004203.txt
#
# Tamamlandı: 0508_004206.txt
#
# Tamamlandı: 0508_004209.txt
#
# Tamamlandı: 0508_004212.txt
#
# Tamamlandı: 0508_004215.txt
#
# Tamamlandı: 0508_004218.txt
#
# Tamamlandı: 0508_004221.txt
#
# Tamamlandı: 0508_004224.txt
#
# Tamamlandı: 0508_004227.txt
#
# Tamamlandı: 0508_004230.txt
#
# Tamamlandı: 0508_004233.txt
#
# Tamamlandı: 0508_004236.txt
#
# Tamamlandı: 0508_004239.txt
#
# Tamamlandı: 0508_004242.txt
#
# Tamamlandı: 0508_004245.txt
#
# Tamamlandı: 0508_004248.txt
#
# Tamamlandı: 0508_004251.txt
#
# Tamamlandı: 0508_004254.txt
#
# Tamamlandı: 0508_004257.txt
#
# Tamamlandı: 0508_004260.txt
#
# Tamamlandı: 0508_004263.txt
#
# Tamamlandı: 0508_004266.txt
#
# Tamamlandı: 0508_004269.txt
#
# Tamamlandı: 0508_004272.txt
#
# Tamamlandı: 0508_004275.txt
#
# Tamamlandı: 0508_004278.txt
#
# Tamamlandı: 0508_004281.txt
#
# Tamamlandı: 0508_004284.txt
#
# Tamamlandı: 0508_004287.txt
#
# Tamamlandı: 0508_004290.txt
#
# Tamamlandı: 0508_004293.txt
#
# Tamamlandı: 0508_004296.txt
#
# Tamamlandı: 0508_004299.txt
#
# Tamamlandı: 0508_004302.txt
#
# Tamamlandı: 0508_004305.txt
#
# Tamamlandı: 0508_004308.txt
#
# Tamamlandı: 0508_004311.txt
#
# Tamamlandı: 0508_004314.txt
#
# Tamamlandı: 0508_004317.txt
#
# Tamamlandı: 0508_004320.txt
#
# Tamamlandı: 0508_004323.txt
#
# Tamamlandı: 0508_004326.txt
#
# Tamamlandı: 0508_004329.txt
#
# Tamamlandı: 0508_004332.txt
#
# Tamamlandı: 0508_004335.txt
#
# Tamamlandı: 0508_004338.txt
#
# Tamamlandı: 0508_004341.txt
#
# Tamamlandı: 0508_004344.txt
#
# Tamamlandı: 0508_004347.txt
#
# Tamamlandı: 0508_004350.txt
#
# Tamamlandı: 0508_004353.txt
#
# Tamamlandı: 0508_004356.txt
#
# Tamamlandı: 0508_004359.txt
#
# Tamamlandı: 0508_004362.txt
#
# Tamamlandı: 0508_004365.txt
#
# Tamamlandı: 0508_004368.txt
#
# Tamamlandı: 0508_004371.txt
#
# Tamamlandı: 0508_004374.txt
#
# Tamamlandı: 0508_004377.txt
#
# Tamamlandı: 0508_004380.txt
#
# Tamamlandı: 0508_004383.txt
#
# Tamamlandı: 0508_004386.txt
#
# Tamamlandı: 0508_004389.txt
#
# Tamamlandı: 0508_004392.txt
#
# Tamamlandı: 0508_004395.txt
#
# Tamamlandı: 0508_004398.txt
#
# Tamamlandı: 0508_004401.txt
#
# Tamamlandı: 0508_004404.txt
#
# Tamamlandı: 0508_004407.txt
#
# Tamamlandı: 0508_004410.txt
#
# Tamamlandı: 0508_004413.txt
#
# Tamamlandı: 0508_004416.txt
#
# Tamamlandı: 0508_004419.txt
#
# Tamamlandı: 0508_004422.txt
#
# Tamamlandı: 0508_004425.txt
#
# Tamamlandı: 0508_004428.txt
#
# Tamamlandı: 0508_004431.txt
#
# Tamamlandı: 0508_004434.txt
#
# Tamamlandı: 0508_004437.txt
#
# Tamamlandı: 0508_004440.txt
#
# Tamamlandı: 0508_004443.txt
#
# Tamamlandı: 0508_004446.txt
#
# Tamamlandı: 0508_004449.txt
#
# Tamamlandı: 0508_004452.txt
#
# Tamamlandı: 0508_004455.txt
#
# Tamamlandı: 0508_004458.txt
#
# Tamamlandı: 0508_004461.txt
#
# Tamamlandı: 0508_004464.txt
#
# Tamamlandı: 0508_004467.txt
#
# Tamamlandı: 0508_004470.txt
#
# Tamamlandı: 0508_004473.txt
#
# Tamamlandı: 0508_004476.txt
#
# Tamamlandı: 0508_004479.txt
#
# Tamamlandı: 0508_004482.txt
#
# Tamamlandı: 0508_004485.txt
#
# Tamamlandı: 0508_004488.txt
#
# Tamamlandı: 0508_004491.txt
#
# Tamamlandı: 0508_004494.txt
#
# Tamamlandı: 0508_004497.txt
#
# Tamamlandı: 0508_004500.txt
#
# Tamamlandı: 0508_004503.txt
#
# Tamamlandı: 0508_004506.txt
#
# Tamamlandı: 0508_004509.txt
#
# Tamamlandı: 0508_004512.txt
#
# Tamamlandı: 0508_004515.txt
#
# Tamamlandı: 0508_004518.txt
#
# Tamamlandı: 0508_004521.txt
#
# Tamamlandı: 0508_004524.txt
#
# Tamamlandı: 0508_004527.txt
#
# Tamamlandı: 0508_004530.txt
#
# Tamamlandı: 0508_004533.txt
#
# Tamamlandı: 0508_004536.txt
#
# Tamamlandı: 0508_004539.txt
#
# Tamamlandı: 0508_004542.txt
#
# Tamamlandı: 0508_004545.txt
#
# Tamamlandı: 0508_004548.txt
#
# Tamamlandı: 0508_004551.txt
#
# Tamamlandı: 0508_004554.txt
#
# Tamamlandı: 0508_004557.txt
#
# Tamamlandı: 0508_004560.txt
#
# Tamamlandı: 0508_004563.txt
#
# Tamamlandı: 0508_004566.txt
#
# Tamamlandı: 0508_004569.txt
#
# Tamamlandı: 0508_004572.txt
#
# Tamamlandı: 0508_004575.txt
#
# Tamamlandı: 0508_004578.txt
#
# Tamamlandı: 0508_004581.txt
#
# Tamamlandı: 0508_004584.txt
#
# [0508_004587.txt] Silinen: 1 0.144531 0.420833 0.131771 0.245370  (IoU=0.97)
# Tamamlandı: 0508_004587.txt
#
# Tamamlandı: 0508_004590.txt
#
# Tamamlandı: 0508_004593.txt
#
# Tamamlandı: 0508_004596.txt
#
# Tamamlandı: 0508_004599.txt
#
# Tamamlandı: 0508_004602.txt
#
# Tamamlandı: 0508_004605.txt
#
# Tamamlandı: 0508_004608.txt
#
# Tamamlandı: 0508_004611.txt
#
# Tamamlandı: 0508_004614.txt
#
# Tamamlandı: 0508_004617.txt
#
# Tamamlandı: 0508_004620.txt
#
# Tamamlandı: 0508_004623.txt
#
# Tamamlandı: 0508_004626.txt
#
# Tamamlandı: 0508_004629.txt
#
# Tamamlandı: 0508_004632.txt
#
# Tamamlandı: 0508_004635.txt
#
# Tamamlandı: 0508_004638.txt
#
# Tamamlandı: 0508_004641.txt
#
# Tamamlandı: 0508_004644.txt
#
# Tamamlandı: 0508_004647.txt
#
# Tamamlandı: 0508_004650.txt
#
# Tamamlandı: 0508_004653.txt
#
# Tamamlandı: 0508_004656.txt
#
# Tamamlandı: 0508_004659.txt
#
# Tamamlandı: 0508_004662.txt
#
# Tamamlandı: 0508_004665.txt
#
# Tamamlandı: 0508_004668.txt
#
# Tamamlandı: 0508_004671.txt
#
# Tamamlandı: 0508_004674.txt
#
# Tamamlandı: 0508_004677.txt
#
# Tamamlandı: 0508_004680.txt
#
# Tamamlandı: 0508_004683.txt
#
# Tamamlandı: 0508_004686.txt
#
# Tamamlandı: 0508_004689.txt
#
# Tamamlandı: 0508_004692.txt
#
# Tamamlandı: 0508_004695.txt
#
# Tamamlandı: 0508_004698.txt
#
# Tamamlandı: 0508_004701.txt
#
# Tamamlandı: 0508_004704.txt
#
# Tamamlandı: 0508_004707.txt
#
# Tamamlandı: 0508_004710.txt
#
# Tamamlandı: 0508_004713.txt
#
# Tamamlandı: 0508_004716.txt
#
# Tamamlandı: 0508_004719.txt
#
# Tamamlandı: 0508_004722.txt
#
# Tamamlandı: 0508_004725.txt
#
# Tamamlandı: 0508_004728.txt
#
# Tamamlandı: 0508_004731.txt
#
# Tamamlandı: 0508_004734.txt
#
# Tamamlandı: 0508_004737.txt
#
# Tamamlandı: 0508_004740.txt
#
# Tamamlandı: 0508_004743.txt
#
# Tamamlandı: 0508_004746.txt
#
# Tamamlandı: 0508_004749.txt
#
# Tamamlandı: 0508_004752.txt
#
# Tamamlandı: 0508_004755.txt
#
# Tamamlandı: 0508_004758.txt
#
# Tamamlandı: 0508_004761.txt
#
# Tamamlandı: 0508_004764.txt
#
# Tamamlandı: 0508_004767.txt
#
# Tamamlandı: 0508_004770.txt
#
# Tamamlandı: 0508_004773.txt
#
# Tamamlandı: 0508_004776.txt
#
# Tamamlandı: 0508_004779.txt
#
# Tamamlandı: 0508_004782.txt
#
# Tamamlandı: 0508_004785.txt
#
# Tamamlandı: 0508_004788.txt
#
# Tamamlandı: 0508_004791.txt
#
# Tamamlandı: 0508_004794.txt
#
# Tamamlandı: 0508_004797.txt
#
# Tamamlandı: 0508_004800.txt
#
# Tamamlandı: 0508_004803.txt
#
# Tamamlandı: 0508_004806.txt
#
# Tamamlandı: 0508_004809.txt
#
# Tamamlandı: 0508_004812.txt
#
# Tamamlandı: 0508_004815.txt
#
# Tamamlandı: 0508_004818.txt
#
# Tamamlandı: 0508_004821.txt
#
# Tamamlandı: 0508_004824.txt
#
# Tamamlandı: 0508_004827.txt
#
# Tamamlandı: 0508_004830.txt
#
# Tamamlandı: 0508_004833.txt
#
# Tamamlandı: 0508_004836.txt
#
# Tamamlandı: 0508_004839.txt
#
# Tamamlandı: 0508_004842.txt
#
# Tamamlandı: 0508_004845.txt
#
# Tamamlandı: 0508_004848.txt
#
# Tamamlandı: 0508_004851.txt
#
# Tamamlandı: 0508_004854.txt
#
# Tamamlandı: 0508_004857.txt
#
# Tamamlandı: 0508_004860.txt
#
# Tamamlandı: 0508_004863.txt
#
# Tamamlandı: 0508_004866.txt
#
# Tamamlandı: 0508_004869.txt
#
# Tamamlandı: 0508_004872.txt
#
# Tamamlandı: 0508_004875.txt
#
# Tamamlandı: 0508_004878.txt
#
# Tamamlandı: 0508_004881.txt
#
# Tamamlandı: 0508_004884.txt
#
# Tamamlandı: 0508_004887.txt
#
# Tamamlandı: 0508_004890.txt
#
# Tamamlandı: 0508_004893.txt
#
# Tamamlandı: 0508_004896.txt
#
# Tamamlandı: 0508_004899.txt
#
# Tamamlandı: 0508_004902.txt
#
# Tamamlandı: 0508_004905.txt
#
# Tamamlandı: 0508_004908.txt
#
# Tamamlandı: 0508_004911.txt
#
# Tamamlandı: 0508_004914.txt
#
# Tamamlandı: 0508_004917.txt
#
# Tamamlandı: 0508_004920.txt
#
# Tamamlandı: 0508_004923.txt
#
# Tamamlandı: 0508_004926.txt
#
# Tamamlandı: 0508_004929.txt
#
# Tamamlandı: 0508_004932.txt
#
# Tamamlandı: 0508_004935.txt
#
# Tamamlandı: 0508_004938.txt
#
# Tamamlandı: 0508_004941.txt
#
# Tamamlandı: 0508_004944.txt
#
# Tamamlandı: 0508_004947.txt
#
# Tamamlandı: 0508_004950.txt
#
# Tamamlandı: 0508_004953.txt
#
# Tamamlandı: 0508_004956.txt
#
# Tamamlandı: 0508_004959.txt
#
# Tamamlandı: 0508_004962.txt
#
# Tamamlandı: 0508_004965.txt
#
# Tamamlandı: 0508_004968.txt
#
# Tamamlandı: 0508_004971.txt
#
# Tamamlandı: 0508_004974.txt
#
# Tamamlandı: 0508_004977.txt
#
# Tamamlandı: 0508_004980.txt
#
# Tamamlandı: 0508_004983.txt
#
# Tamamlandı: 0508_004986.txt
#
# Tamamlandı: 0508_004989.txt
#
# Tamamlandı: 0508_004992.txt
#
# Tamamlandı: 0508_004995.txt
#
# Tamamlandı: 0508_004998.txt
#
# Tamamlandı: 0508_005001.txt
#
# Tamamlandı: 0508_005004.txt
#
# Tamamlandı: 0508_005007.txt
#
# Tamamlandı: 0508_005010.txt
#
# Tamamlandı: 0508_005013.txt
#
# Tamamlandı: 0508_005016.txt
#
# Tamamlandı: 0508_005019.txt
#
# Tamamlandı: 0508_005022.txt
#
# Tamamlandı: 0508_005025.txt
#
# Tamamlandı: 0508_005028.txt
#
# Tamamlandı: 0508_005031.txt
#
# Tamamlandı: 0508_005034.txt
#
# Tamamlandı: 0508_005037.txt
#
# Tamamlandı: 0508_005040.txt
#
# Tamamlandı: 0508_005043.txt
#
# Tamamlandı: 0508_005046.txt
#
# Tamamlandı: 0508_005049.txt
#
# Tamamlandı: 0508_005052.txt
#
# Tamamlandı: 0508_005055.txt
#
# Tamamlandı: 0508_005058.txt
#
# Tamamlandı: 0508_005061.txt
#
# Tamamlandı: 0508_005064.txt
#
# Tamamlandı: 0508_005067.txt
#
# Tamamlandı: 0508_005070.txt
#
# Tamamlandı: 0508_005073.txt
#
# Tamamlandı: 0508_005076.txt
#
# Tamamlandı: 0508_005079.txt
#
# Tamamlandı: 0508_005082.txt
#
# Tamamlandı: 0508_005085.txt
#
# Tamamlandı: 0508_005088.txt
#
# Tamamlandı: 0508_005091.txt
#
# Tamamlandı: 0508_005094.txt
#
# Tamamlandı: 0508_005097.txt
#
# Tamamlandı: 0508_005100.txt
#
# Tamamlandı: 0508_005103.txt
#
# Tamamlandı: 0508_005106.txt
#
# Tamamlandı: 0508_005109.txt
#
# Tamamlandı: 0508_005112.txt
#
# Tamamlandı: 0508_005115.txt
#
# Tamamlandı: 0508_005118.txt
#
# Tamamlandı: 0508_005121.txt
#
# Tamamlandı: 0508_005124.txt
#
# Tamamlandı: 0508_005127.txt
#
# Tamamlandı: 0508_005130.txt
#
# Tamamlandı: 0508_005133.txt
#
# Tamamlandı: 0508_005136.txt
#
# Tamamlandı: 0508_005139.txt
#
# Tamamlandı: 0508_005142.txt
#
# Tamamlandı: 0508_005145.txt
#
# Tamamlandı: 0508_005148.txt
#
# Tamamlandı: 0508_005151.txt
#
# Tamamlandı: 0508_005154.txt
#
# Tamamlandı: 0508_005157.txt
#
# Tamamlandı: 0508_005160.txt
#
# Tamamlandı: 0508_005163.txt
#
# Tamamlandı: 0508_005166.txt
#
# Tamamlandı: 0508_005169.txt
#
# Tamamlandı: 0508_005172.txt
#
# Tamamlandı: 0508_005175.txt
#
# Tamamlandı: 0508_005178.txt
#
# Tamamlandı: 0508_005181.txt
#
# Tamamlandı: 0508_005184.txt
#
# Tamamlandı: 0508_005187.txt
#
# Tamamlandı: 0508_005190.txt
#
# Tamamlandı: 0508_005193.txt
#
# Tamamlandı: 0508_005196.txt
#
# Tamamlandı: 0508_005199.txt
#
# Tamamlandı: 0508_005202.txt
#
# Tamamlandı: 0508_005205.txt
#
# Tamamlandı: 0508_005208.txt
#
# Tamamlandı: 0508_005211.txt
#
# Tamamlandı: 0508_005214.txt
#
# Tamamlandı: 0508_005217.txt
#
# Tamamlandı: 0508_005220.txt
#
# Tamamlandı: 0508_005223.txt
#
# Tamamlandı: 0508_005226.txt
#
# Tamamlandı: 0508_005229.txt
#
# Tamamlandı: 0508_005232.txt
#
# Tamamlandı: 0508_005235.txt
#
# Tamamlandı: 0508_005238.txt
#
# Tamamlandı: 0508_005241.txt
#
# Tamamlandı: 0508_005244.txt
#
# Tamamlandı: 0508_005247.txt
#
# Tamamlandı: 0508_005250.txt
#
# Tamamlandı: 0508_005253.txt
#
# Tamamlandı: 0508_005256.txt
#
# Tamamlandı: 0508_005259.txt
#
# Tamamlandı: 0508_005262.txt
#
# Tamamlandı: 0508_005265.txt
#
# Tamamlandı: 0508_005268.txt
#
# Tamamlandı: 0508_005271.txt
#
# Tamamlandı: 0508_005274.txt
#
# Tamamlandı: 0508_005277.txt
#
# Tamamlandı: 0508_005280.txt
#
# Tamamlandı: 0508_005283.txt
#
# Tamamlandı: 0508_005286.txt
#
# Tamamlandı: 0508_005289.txt
#
# Tamamlandı: 0508_005292.txt
#
# Tamamlandı: 0508_005295.txt
#
# Tamamlandı: 0508_005298.txt
#
# Tamamlandı: 0508_005301.txt
#
# Tamamlandı: 0508_005304.txt
#
# Tamamlandı: 0508_005307.txt
#
# Tamamlandı: 0508_005310.txt
#
# Tamamlandı: 0508_005313.txt
#
# Tamamlandı: 0508_005316.txt
#
# Tamamlandı: 0508_005319.txt
#
# Tamamlandı: 0508_005322.txt
#
# Tamamlandı: 0508_005325.txt
#
# Tamamlandı: 0508_005328.txt
#
# Tamamlandı: 0508_005331.txt
#
# Tamamlandı: 0508_005334.txt
#
# Tamamlandı: 0508_005337.txt
#
# Tamamlandı: 0508_005340.txt
#
# Tamamlandı: 0508_005343.txt
#
# Tamamlandı: 0508_005346.txt
#
# Tamamlandı: 0508_005349.txt
#
# Tamamlandı: 0508_005352.txt
#
# Tamamlandı: 0508_005355.txt
#
# Tamamlandı: 0508_005358.txt
#
# Tamamlandı: 0508_005361.txt
#
# Tamamlandı: 0508_005364.txt
#
# Tamamlandı: 0508_005367.txt
#
# Tamamlandı: 0508_005370.txt
#
# Tamamlandı: 0508_005373.txt
#
# Tamamlandı: 0508_005376.txt
#
# Tamamlandı: 0508_005379.txt
#
# Tamamlandı: 0508_005382.txt
#
# Tamamlandı: 0508_005385.txt
#
# Tamamlandı: 0508_005388.txt
#
# Tamamlandı: 0508_005391.txt
#
# Tamamlandı: 0508_005394.txt
#
# Tamamlandı: 0508_005397.txt
#
# Tamamlandı: 0508_005400.txt
#
# Tamamlandı: 0508_005403.txt
#
# Tamamlandı: 0508_005406.txt
#
# Tamamlandı: 0508_005409.txt
#
# Tamamlandı: 0508_005412.txt
#
# Tamamlandı: 0508_005415.txt
#
# Tamamlandı: 0508_005418.txt
#
# Tamamlandı: 0508_005421.txt
#
# Tamamlandı: 0508_005424.txt
#
# Tamamlandı: 0508_005427.txt
#
# Tamamlandı: 0508_005430.txt
#
# Tamamlandı: 0508_005433.txt
#
# Tamamlandı: 0508_005436.txt
#
# Tamamlandı: 0508_005439.txt
#
# Tamamlandı: 0508_005442.txt
#
# Tamamlandı: 0508_005445.txt
#
# Tamamlandı: 0508_005448.txt
#
# Tamamlandı: 0508_005451.txt
#
# Tamamlandı: 0508_005454.txt
#
# Tamamlandı: 0508_005457.txt
#
# Tamamlandı: 0508_005460.txt
#
# Tamamlandı: 0508_005463.txt
#
# Tamamlandı: 0508_005466.txt
#
# Tamamlandı: 0508_005469.txt
#
# Tamamlandı: 0508_005472.txt
#
# Tamamlandı: 0508_005475.txt
#
# Tamamlandı: 0508_005478.txt
#
# Tamamlandı: 0508_005481.txt
#
# Tamamlandı: 0508_005484.txt
#
# Tamamlandı: 0508_005487.txt
#
# Tamamlandı: 0508_005490.txt
#
# Tamamlandı: 0508_005493.txt
#
# Tamamlandı: 0508_005496.txt
#
# Tamamlandı: 0508_005499.txt
#
# Tamamlandı: 0508_005502.txt
#
# Tamamlandı: 0508_005505.txt
#
# Tamamlandı: 0508_005508.txt
#
# Tamamlandı: 0508_005511.txt
#
# Tamamlandı: 0508_005514.txt
#
# Tamamlandı: 0508_005517.txt
#
# Tamamlandı: 0508_005520.txt
#
# Tamamlandı: 0508_005523.txt
#
# Tamamlandı: 0508_005526.txt
#
# Tamamlandı: 0508_005529.txt
#
# Tamamlandı: 0508_005532.txt
#
# Tamamlandı: 0508_005535.txt
#
# Tamamlandı: 0508_005538.txt
#
# Tamamlandı: 0508_005541.txt
#
# Tamamlandı: 0508_005544.txt
#
# Tamamlandı: 0508_005547.txt
#
# Tamamlandı: 0508_005550.txt
#
# Tamamlandı: 0508_005553.txt
#
# Tamamlandı: 0508_005556.txt
#
# Tamamlandı: 0508_005559.txt
#
# Tamamlandı: 0508_005562.txt
#
# Tamamlandı: 0508_005565.txt
#
# Tamamlandı: 0508_005568.txt
#
# Tamamlandı: 0508_005571.txt
#
# Tamamlandı: 0508_005574.txt
#
# Tamamlandı: 0508_005577.txt
#
# Tamamlandı: 0508_005580.txt
#
# Tamamlandı: 0508_005583.txt
#
# Tamamlandı: 0508_005586.txt
#
# Tamamlandı: 0508_005589.txt
#
# Tamamlandı: 0508_005592.txt
#
# Tamamlandı: 0508_005595.txt
#
# Tamamlandı: 0508_005598.txt
#
# Tamamlandı: 0508_005601.txt
#
# Tamamlandı: 0508_005604.txt
#
# Tamamlandı: 0508_005607.txt
#
# Tamamlandı: 0508_005610.txt
#
# Tamamlandı: 0508_005613.txt
#
# Tamamlandı: 0508_005616.txt
#
# Tamamlandı: 0508_005619.txt
#
# Tamamlandı: 0508_005622.txt
#
# Tamamlandı: 0508_005625.txt
#
# Tamamlandı: 0508_005628.txt
#
# Tamamlandı: 0508_005631.txt
#
# Tamamlandı: 0508_005634.txt
#
# Tamamlandı: 0508_005637.txt
#
# Tamamlandı: 0508_005640.txt
#
# Tamamlandı: 0508_005643.txt
#
# Tamamlandı: 0508_005646.txt
#
# Tamamlandı: 0508_005649.txt
#
# Tamamlandı: 0508_005652.txt
#
# Tamamlandı: 0508_005655.txt
#
# Tamamlandı: 0508_005658.txt
#
# Tamamlandı: 0508_005661.txt
#
# Tamamlandı: 0508_005664.txt
#
# Tamamlandı: 0508_005667.txt
#
# Tamamlandı: 0508_005670.txt
#
# Tamamlandı: 0508_005673.txt
#
# Tamamlandı: 0508_005676.txt
#
# Tamamlandı: 0508_005679.txt
#
# Tamamlandı: 0508_005682.txt
#
# Tamamlandı: 0508_005685.txt
#
# Tamamlandı: 0508_005688.txt
#
# Tamamlandı: 0508_005691.txt
#
# Tamamlandı: 0508_005694.txt
#
# Tamamlandı: 0508_005697.txt
#
# Tamamlandı: 0508_005700.txt
#
# Tamamlandı: 0508_005703.txt
#
# Tamamlandı: 0508_005706.txt
#
# Tamamlandı: 0508_005709.txt
#
# Tamamlandı: 0508_005712.txt
#
# Tamamlandı: 0508_005715.txt
#
# Tamamlandı: 0508_005718.txt
#
# Tamamlandı: 0508_005721.txt
#
# Tamamlandı: 0508_005724.txt
#
# Tamamlandı: 0508_005727.txt
#
# Tamamlandı: 0508_005730.txt
#
# Tamamlandı: 0508_005733.txt
#
# Tamamlandı: 0508_005736.txt
#
# Tamamlandı: 0508_005739.txt
#
# Tamamlandı: 0508_005742.txt
#
# Tamamlandı: 0508_005745.txt
#
# Tamamlandı: 0508_005748.txt
#
# Tamamlandı: 0508_005751.txt
#
# Tamamlandı: 0508_005754.txt
#
# Tamamlandı: 0508_005757.txt
#
# Tamamlandı: 0508_005760.txt
#
# Tamamlandı: 0508_005763.txt
#
# Tamamlandı: 0508_005766.txt
#
# Tamamlandı: 0508_005769.txt
#
# Tamamlandı: 0508_005772.txt
#
# Tamamlandı: 0508_005775.txt
#
# Tamamlandı: 0508_005778.txt
#
# Tamamlandı: 0508_005781.txt
#
# Tamamlandı: 0508_005784.txt
#
# Tamamlandı: 0508_005787.txt
#
# Tamamlandı: 0508_005790.txt
#
# Tamamlandı: 0508_005793.txt
#
# Tamamlandı: 0508_005796.txt
#
# Tamamlandı: 0508_005799.txt
#
# Tamamlandı: 0508_005802.txt
#
# Tamamlandı: 0508_005805.txt
#
# Tamamlandı: 0508_005808.txt
#
# Tamamlandı: 0508_005811.txt
#
# Tamamlandı: 0508_005814.txt
#
# Tamamlandı: 0508_005817.txt
#
# Tamamlandı: 0508_005820.txt
#
# Tamamlandı: 0508_005823.txt
#
# Tamamlandı: 0508_005826.txt
#
# Tamamlandı: 0508_005829.txt
#
# Tamamlandı: 0508_005832.txt
