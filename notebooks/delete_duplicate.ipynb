# %%
import os
import numpy as np

import math
from collections import Counter

def komsu_oylama(filepath, k=5, radius=None, alpha=0.75, weight=True):
    """
    • radius=None  → k-en yakın; radius=px  → yarıçap içinde
    • weight=True  → 1/dist ağırlıklı oy; False → düz sayım
    • alpha        → baskın sınıf oran eşiği (0–1). Karşılanmazsa kutu değişmez
    """
    import math
    from collections import defaultdict, Counter

    with open(filepath) as f:
        lines = [l.strip() for l in f if l.strip()]

    entries, centers = [], []
    for l in lines:
        p   = l.split()
        cls = int(float(p[0]))
        cx, cy, w, h = map(float, p[1:5])
        conf = float(p[5]) if len(p) > 5 else None
        entries.append([cls, (cx, cy, w, h), conf])
        centers.append((cx, cy))

    new_cls = []
    for i, (cls_i, (cx_i, cy_i, w_i, h_i), _) in enumerate(entries):
        if cls_i == 4:                 # class 4'u koru
            new_cls.append(cls_i)
            continue

        # uzaklık listesi
        dists = [(math.hypot(cx_i - cx_j, cy_i - cy_j), j)
                 for j, (cx_j, cy_j) in enumerate(centers) if j != i]
        dists.sort(key=lambda x: x[0])

        # komşu seçim stratejisi
        neighbors = []
        if radius is not None:
            neighbors = [j for d, j in dists if d <= radius]
        else:
            neighbors = [j for _, j in dists[:k]]

        if not neighbors:
            new_cls.append(cls_i)
            continue

        # oy toplama
        scores = defaultdict(float)
        for j in neighbors:
            cls_j = entries[j][0]
            wght = 1.0 / (dists[[idx for idx, jj in enumerate(neighbors) if jj == j][0]][0] + 1e-6) if weight else 1.0
            scores[cls_j] += wght

        # kazanan sınıf
        winner, win_score = max(scores.items(), key=lambda x: x[1])
        total_score = sum(scores.values())

        if win_score / total_score >= alpha:
            new_cls.append(winner)
        else:
            new_cls.append(cls_i)

    # dosyayı güncelle
    with open(filepath, "w") as f:
        for (old_cls, box, conf), cls in zip(entries, new_cls):
            line = f"{cls} {' '.join(f'{x:.6f}' for x in box)}"
            if conf is not None:
                line += f" {conf:.6f}"
            f.write(line + "\n")

def compute_iou(box1, box2):
    x1_min = box1[0] - box1[2] / 2
    y1_min = box1[1] - box1[3] / 2
    x1_max = box1[0] + box1[2] / 2
    y1_max = box1[1] + box1[3] / 2

    x2_min = box2[0] - box2[2] / 2
    y2_min = box2[1] - box2[3] / 2
    x2_max = box2[0] + box2[2] / 2
    y2_max = box2[1] + box2[3] / 2

    inter_x_min = max(x1_min, x2_min)
    inter_y_min = max(y1_min, y2_min)
    inter_x_max = min(x1_max, x2_max)
    inter_y_max = min(y1_max, y2_max)

    inter_area = max(0, inter_x_max - inter_x_min) * max(0, inter_y_max - inter_y_min)
    area1 = (x1_max - x1_min) * (y1_max - y1_min)
    area2 = (x2_max - x2_min) * (y2_max - y2_min)

    union_area = area1 + area2 - inter_area
    return inter_area / union_area if union_area > 0 else 0

def remove_duplicates_from_file(filepath, iou_threshold=1):
    #print(f"İşleniyor: {filepath}")
    with open(filepath, 'r') as f:
        lines = f.readlines()

    boxes = []
    for line in lines:
        parts = line.strip().split()
        cls = int(parts[0])
        box   = list(map(float, parts[1:5]))  
        boxes.append((cls, box, line.strip()))

    keep = []
    used = [False] * len(boxes)
    
    for i in range(len(boxes)):
        if used[i]:
            continue
        cls1, box1, original1 = boxes[i]
        keep.append((cls1, box1))
        used[i] = True          # ← eklendi
        for j in range(i + 1, len(boxes)):
            cls2, box2, original2 = boxes[j]
            if not used[j]:
                iou = compute_iou(box1, box2)
                if iou > iou_threshold:
                    used[j] = True
                    print(f"[{os.path.basename(filepath)}] Silinen: {original2}  (IoU={iou:.2f})")

    with open(filepath, 'w') as f:
        for cls, box in keep:
            f.write(f"{cls} {' '.join(map(str, box))}\n")

def process_labels_folder(labels_folder, iou_threshold=0.7):
    for filename in os.listdir(labels_folder):
        if filename.endswith('.txt') and filename != "classes.txt":
            filepath = os.path.join(labels_folder, filename)

            # 1) önce KOPYA kutuları sil
            remove_duplicates_from_file(filepath, iou_threshold)

            # 2) sonra komşu oylaması
            #komsu_oylama(filepath, k=10, radius=None, alpha=0.85, weight=True)        # <-- DÜZELTİLDİ

            print(f"Tamamlandı: {filename}\n")
 

if __name__ == "__main__":
    labels_path = "LABEL_PATH"  # Bu klasör yolunu gerektiği gibi değiştir
    
    iou_threshold = 0     # Buradan ayarlanabilir
    process_labels_folder(labels_path, iou_threshold)
# Out:
# Tamamlandı: Maxi_Tum_0411_015123.txt
#
# Tamamlandı: Maxi_Tum_0411_015126.txt
#
# Tamamlandı: Maxi_Tum_0411_015129.txt
#
# Tamamlandı: Maxi_Tum_0411_015132.txt
#
# Tamamlandı: Maxi_Tum_0411_015135.txt
#
# Tamamlandı: Maxi_Tum_0411_015138.txt
#
# Tamamlandı: Maxi_Tum_0411_015141.txt
#
# Tamamlandı: Maxi_Tum_0411_015144.txt
#
# Tamamlandı: Maxi_Tum_0411_015147.txt
#
# Tamamlandı: Maxi_Tum_0411_015150.txt
#
# Tamamlandı: Maxi_Tum_0411_015153.txt
#
# Tamamlandı: Maxi_Tum_0411_015156.txt
#
# Tamamlandı: Maxi_Tum_0411_015159.txt
#
# Tamamlandı: Maxi_Tum_0411_015162.txt
#
# Tamamlandı: Maxi_Tum_0411_015165.txt
#
# Tamamlandı: Maxi_Tum_0411_015168.txt
#
# Tamamlandı: Maxi_Tum_0411_015171.txt
#
# Tamamlandı: Maxi_Tum_0411_015174.txt
#
# Tamamlandı: Maxi_Tum_0411_015177.txt
#
# Tamamlandı: Maxi_Tum_0411_015180.txt
#
# Tamamlandı: Maxi_Tum_0411_015183.txt
#
# [Maxi_Tum_0411_015186.txt] Silinen: 5 0.4800465901692708 0.36817338731553817 0.46081720987955727 0.7363467746310763  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015186.txt
#
# [Maxi_Tum_0411_015189.txt] Silinen: 5 0.5272084236145019 0.3780318648726852 0.4580942153930664 0.7560637297453704  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015189.txt
#
# [Maxi_Tum_0411_015192.txt] Silinen: 4 0.5599822998046875 0.3823587205674913 0.45373191833496096 0.7647174411349826  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015192.txt
#
# Tamamlandı: Maxi_Tum_0411_015195.txt
#
# Tamamlandı: Maxi_Tum_0411_015198.txt
#
# Tamamlandı: Maxi_Tum_0411_015201.txt
#
# Tamamlandı: Maxi_Tum_0411_015204.txt
#
# [Maxi_Tum_0411_015207.txt] Silinen: 5 0.7776556650797526 0.39623418737340854 0.3826482137044271 0.7437148482711227  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015207.txt
#
# [Maxi_Tum_0411_015210.txt] Silinen: 5 0.8084260940551757 0.4026845296223958 0.3626995086669922 0.7337436252170139  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_015210.txt
#
# Tamamlandı: Maxi_Tum_0411_015213.txt
#
# Tamamlandı: Maxi_Tum_0411_015216.txt
#
# Tamamlandı: Maxi_Tum_0411_015219.txt
#
# Tamamlandı: Maxi_Tum_0411_015222.txt
#
# Tamamlandı: Maxi_Tum_0411_015225.txt
#
# Tamamlandı: Maxi_Tum_0411_015228.txt
#
# Tamamlandı: Maxi_Tum_0411_015231.txt
#
# Tamamlandı: Maxi_Tum_0411_015234.txt
#
# Tamamlandı: Maxi_Tum_0411_015237.txt
#
# Tamamlandı: Maxi_Tum_0411_015240.txt
#
# Tamamlandı: Maxi_Tum_0411_015243.txt
#
# Tamamlandı: Maxi_Tum_0411_015246.txt
#
# Tamamlandı: Maxi_Tum_0411_015249.txt
#
# Tamamlandı: Maxi_Tum_0411_015252.txt
#
# Tamamlandı: Maxi_Tum_0411_015255.txt
#
# Tamamlandı: Maxi_Tum_0411_015258.txt
#
# Tamamlandı: Maxi_Tum_0411_015261.txt
#
# Tamamlandı: Maxi_Tum_0411_015264.txt
#
# Tamamlandı: Maxi_Tum_0411_015267.txt
#
# Tamamlandı: Maxi_Tum_0411_015270.txt
#
# [Maxi_Tum_0411_015273.txt] Silinen: 4 0.16631043752034505 0.39712452358669703 0.3326208750406901 0.7023597717285156  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015273.txt
#
# Tamamlandı: Maxi_Tum_0411_015276.txt
#
# [Maxi_Tum_0411_015279.txt] Silinen: 5 0.23686275482177735 0.3932050069173177 0.39711589813232423 0.7363445705837673  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015279.txt
#
# [Maxi_Tum_0411_015282.txt] Silinen: 4 0.2678201675415039 0.3904805925157335 0.41405086517333983 0.7408585442437066  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015282.txt
#
# Tamamlandı: Maxi_Tum_0411_015285.txt
#
# Tamamlandı: Maxi_Tum_0411_015288.txt
#
# Tamamlandı: Maxi_Tum_0411_015291.txt
#
# Tamamlandı: Maxi_Tum_0411_015294.txt
#
# Tamamlandı: Maxi_Tum_0411_015297.txt
#
# Tamamlandı: Maxi_Tum_0411_015300.txt
#
# Tamamlandı: Maxi_Tum_0411_015303.txt
#
# Tamamlandı: Maxi_Tum_0411_015306.txt
#
# Tamamlandı: Maxi_Tum_0411_015309.txt
#
# Tamamlandı: Maxi_Tum_0411_015312.txt
#
# Tamamlandı: Maxi_Tum_0411_015315.txt
#
# Tamamlandı: Maxi_Tum_0411_015318.txt
#
# Tamamlandı: Maxi_Tum_0411_015321.txt
#
# Tamamlandı: Maxi_Tum_0411_015324.txt
#
# Tamamlandı: Maxi_Tum_0411_015327.txt
#
# Tamamlandı: Maxi_Tum_0411_015330.txt
#
# Tamamlandı: Maxi_Tum_0411_015333.txt
#
# Tamamlandı: Maxi_Tum_0411_015336.txt
#
# Tamamlandı: Maxi_Tum_0411_015339.txt
#
# Tamamlandı: Maxi_Tum_0411_015342.txt
#
# Tamamlandı: Maxi_Tum_0411_015345.txt
#
# Tamamlandı: Maxi_Tum_0411_015348.txt
#
# Tamamlandı: Maxi_Tum_0411_015351.txt
#
# [Maxi_Tum_0411_015354.txt] Silinen: 30 0.15422186851501465 0.46523540638111255 0.3084437370300293 0.6893754464608651  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015354.txt
#
# Tamamlandı: Maxi_Tum_0411_015357.txt
#
# Tamamlandı: Maxi_Tum_0411_015360.txt
#
# Tamamlandı: Maxi_Tum_0411_015363.txt
#
# Tamamlandı: Maxi_Tum_0411_015366.txt
#
# Tamamlandı: Maxi_Tum_0411_015369.txt
#
# [Maxi_Tum_0411_015372.txt] Silinen: 13 0.3823889414469401 0.46562637046531397 0.44600804646809894 0.7723377086498119  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_015372.txt
#
# Tamamlandı: Maxi_Tum_0411_015375.txt
#
# Tamamlandı: Maxi_Tum_0411_015378.txt
#
# Tamamlandı: Maxi_Tum_0411_015381.txt
#
# Tamamlandı: Maxi_Tum_0411_015384.txt
#
# [Maxi_Tum_0411_015387.txt] Silinen: 13 0.6182327270507812 0.470492680867513 0.4461055755615234 0.7833137512207031  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_015387.txt
#
# [Maxi_Tum_0411_015390.txt] Silinen: 13 0.6521678447723389 0.46934373643663196 0.4369938850402832 0.7667249891493055  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_015390.txt
#
# Tamamlandı: Maxi_Tum_0411_015393.txt
#
# [Maxi_Tum_0411_015396.txt] Silinen: 13 0.7332047780354818 0.4654421629729094 0.4063837687174479 0.7450551633481626  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015396.txt
#
# Tamamlandı: Maxi_Tum_0411_015399.txt
#
# [Maxi_Tum_0411_015402.txt] Silinen: 1 0.8128503799438477 0.47124180263943144 0.36525421142578124 0.7208793640136719  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015402.txt
#
# Tamamlandı: Maxi_Tum_0411_015405.txt
#
# Tamamlandı: Maxi_Tum_0411_015408.txt
#
# Tamamlandı: Maxi_Tum_0411_015411.txt
#
# Tamamlandı: Maxi_Tum_0411_015414.txt
#
# Tamamlandı: Maxi_Tum_0411_015417.txt
#
# Tamamlandı: Maxi_Tum_0411_015420.txt
#
# Tamamlandı: Maxi_Tum_0411_015423.txt
#
# Tamamlandı: Maxi_Tum_0411_015426.txt
#
# Tamamlandı: Maxi_Tum_0411_015429.txt
#
# Tamamlandı: Maxi_Tum_0411_015432.txt
#
# Tamamlandı: Maxi_Tum_0411_015435.txt
#
# Tamamlandı: Maxi_Tum_0411_015438.txt
#
# Tamamlandı: Maxi_Tum_0411_015441.txt
#
# Tamamlandı: Maxi_Tum_0411_015444.txt
#
# Tamamlandı: Maxi_Tum_0411_015447.txt
#
# Tamamlandı: Maxi_Tum_0411_015450.txt
#
# Tamamlandı: Maxi_Tum_0411_015453.txt
#
# Tamamlandı: Maxi_Tum_0411_015456.txt
#
# Tamamlandı: Maxi_Tum_0411_015459.txt
#
# Tamamlandı: Maxi_Tum_0411_015462.txt
#
# Tamamlandı: Maxi_Tum_0411_015465.txt
#
# Tamamlandı: Maxi_Tum_0411_015468.txt
#
# Tamamlandı: Maxi_Tum_0411_015471.txt
#
# Tamamlandı: Maxi_Tum_0411_015474.txt
#
# Tamamlandı: Maxi_Tum_0411_015477.txt
#
# Tamamlandı: Maxi_Tum_0411_015480.txt
#
# Tamamlandı: Maxi_Tum_0411_015483.txt
#
# Tamamlandı: Maxi_Tum_0411_015486.txt
#
# Tamamlandı: Maxi_Tum_0411_015489.txt
#
# Tamamlandı: Maxi_Tum_0411_015492.txt
#
# Tamamlandı: Maxi_Tum_0411_015495.txt
#
# Tamamlandı: Maxi_Tum_0411_015498.txt
#
# Tamamlandı: Maxi_Tum_0411_015501.txt
#
# Tamamlandı: Maxi_Tum_0411_015504.txt
#
# Tamamlandı: Maxi_Tum_0411_015507.txt
#
# Tamamlandı: Maxi_Tum_0411_015510.txt
#
# Tamamlandı: Maxi_Tum_0411_015513.txt
#
# Tamamlandı: Maxi_Tum_0411_015516.txt
#
# Tamamlandı: Maxi_Tum_0411_015519.txt
#
# Tamamlandı: Maxi_Tum_0411_015522.txt
#
# Tamamlandı: Maxi_Tum_0411_015525.txt
#
# Tamamlandı: Maxi_Tum_0411_015528.txt
#
# Tamamlandı: Maxi_Tum_0411_015531.txt
#
# Tamamlandı: Maxi_Tum_0411_015534.txt
#
# Tamamlandı: Maxi_Tum_0411_015537.txt
#
# Tamamlandı: Maxi_Tum_0411_015540.txt
#
# Tamamlandı: Maxi_Tum_0411_015543.txt
#
# Tamamlandı: Maxi_Tum_0411_015546.txt
#
# Tamamlandı: Maxi_Tum_0411_015549.txt
#
# Tamamlandı: Maxi_Tum_0411_015552.txt
#
# Tamamlandı: Maxi_Tum_0411_015555.txt
#
# Tamamlandı: Maxi_Tum_0411_015558.txt
#
# Tamamlandı: Maxi_Tum_0411_015561.txt
#
# Tamamlandı: Maxi_Tum_0411_015564.txt
#
# Tamamlandı: Maxi_Tum_0411_015567.txt
#
# Tamamlandı: Maxi_Tum_0411_015570.txt
#
# Tamamlandı: Maxi_Tum_0411_015573.txt
#
# Tamamlandı: Maxi_Tum_0411_015576.txt
#
# Tamamlandı: Maxi_Tum_0411_015579.txt
#
# Tamamlandı: Maxi_Tum_0411_015582.txt
#
# Tamamlandı: Maxi_Tum_0411_015585.txt
#
# Tamamlandı: Maxi_Tum_0411_015588.txt
#
# Tamamlandı: Maxi_Tum_0411_015591.txt
#
# Tamamlandı: Maxi_Tum_0411_015594.txt
#
# Tamamlandı: Maxi_Tum_0411_015597.txt
#
# [Maxi_Tum_0411_015600.txt] Silinen: 5 0.16868216196695965 0.40476596973560475 0.3373643239339193 0.6999992653175636  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015600.txt
#
# Tamamlandı: Maxi_Tum_0411_015603.txt
#
# Tamamlandı: Maxi_Tum_0411_015606.txt
#
# Tamamlandı: Maxi_Tum_0411_015609.txt
#
# Tamamlandı: Maxi_Tum_0411_015612.txt
#
# Tamamlandı: Maxi_Tum_0411_015615.txt
#
# Tamamlandı: Maxi_Tum_0411_015618.txt
#
# Tamamlandı: Maxi_Tum_0411_015621.txt
#
# Tamamlandı: Maxi_Tum_0411_015624.txt
#
# Tamamlandı: Maxi_Tum_0411_015627.txt
#
# Tamamlandı: Maxi_Tum_0411_015630.txt
#
# Tamamlandı: Maxi_Tum_0411_015633.txt
#
# Tamamlandı: Maxi_Tum_0411_015636.txt
#
# Tamamlandı: Maxi_Tum_0411_015639.txt
#
# Tamamlandı: Maxi_Tum_0411_015642.txt
#
# [Maxi_Tum_0411_015645.txt] Silinen: 30 0.8029414176940918 0.41203672620985243 0.37012767791748047 0.7291627671983507  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015645.txt
#
# Tamamlandı: Maxi_Tum_0411_015648.txt
#
# Tamamlandı: Maxi_Tum_0411_015651.txt
#
# Tamamlandı: Maxi_Tum_0411_015654.txt
#
# Tamamlandı: Maxi_Tum_0411_015657.txt
#
# Tamamlandı: Maxi_Tum_0411_015660.txt
#
# Tamamlandı: Maxi_Tum_0411_015663.txt
#
# Tamamlandı: Maxi_Tum_0411_015666.txt
#
# Tamamlandı: Maxi_Tum_0411_015669.txt
#
# Tamamlandı: Maxi_Tum_0411_015672.txt
#
# Tamamlandı: Maxi_Tum_0411_015675.txt
#
# Tamamlandı: Maxi_Tum_0411_015678.txt
#
# Tamamlandı: Maxi_Tum_0411_015681.txt
#
# Tamamlandı: Maxi_Tum_0411_015684.txt
#
# Tamamlandı: Maxi_Tum_0411_015687.txt
#
# Tamamlandı: Maxi_Tum_0411_015690.txt
#
# Tamamlandı: Maxi_Tum_0411_015693.txt
#
# Tamamlandı: Maxi_Tum_0411_015696.txt
#
# Tamamlandı: Maxi_Tum_0411_015699.txt
#
# Tamamlandı: Maxi_Tum_0411_015702.txt
#
# Tamamlandı: Maxi_Tum_0411_015705.txt
#
# Tamamlandı: Maxi_Tum_0411_015708.txt
#
# Tamamlandı: Maxi_Tum_0411_015711.txt
#
# Tamamlandı: Maxi_Tum_0411_015714.txt
#
# Tamamlandı: Maxi_Tum_0411_015717.txt
#
# Tamamlandı: Maxi_Tum_0411_015720.txt
#
# Tamamlandı: Maxi_Tum_0411_015723.txt
#
# Tamamlandı: Maxi_Tum_0411_015726.txt
#
# Tamamlandı: Maxi_Tum_0411_015729.txt
#
# [Maxi_Tum_0411_015732.txt] Silinen: 4 0.2490442117055257 0.3735873752170139 0.40436264673868816 0.7361117892795139  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015732.txt
#
# Tamamlandı: Maxi_Tum_0411_015735.txt
#
# Tamamlandı: Maxi_Tum_0411_015738.txt
#
# Tamamlandı: Maxi_Tum_0411_015741.txt
#
# Tamamlandı: Maxi_Tum_0411_015744.txt
#
# Tamamlandı: Maxi_Tum_0411_015747.txt
#
# [Maxi_Tum_0411_015750.txt] Silinen: 4 0.5097903887430827 0.37794613308376734 0.46418565114339194 0.7558922661675347  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_015750.txt
#
# Tamamlandı: Maxi_Tum_0411_015753.txt
#
# Tamamlandı: Maxi_Tum_0411_015756.txt
#
# Tamamlandı: Maxi_Tum_0411_015759.txt
#
# Tamamlandı: Maxi_Tum_0411_015762.txt
#
# Tamamlandı: Maxi_Tum_0411_015765.txt
#
# Tamamlandı: Maxi_Tum_0411_015768.txt
#
# Tamamlandı: Maxi_Tum_0411_015771.txt
#
# Tamamlandı: Maxi_Tum_0411_015774.txt
#
# Tamamlandı: Maxi_Tum_0411_015777.txt
#
# Tamamlandı: Maxi_Tum_0411_015780.txt
#
# Tamamlandı: Maxi_Tum_0411_015783.txt
#
# Tamamlandı: Maxi_Tum_0411_015786.txt
#
# Tamamlandı: Maxi_Tum_0411_015789.txt
#
# Tamamlandı: Maxi_Tum_0411_015792.txt
#
# Tamamlandı: Maxi_Tum_0411_015795.txt
#
# Tamamlandı: Maxi_Tum_0411_015798.txt
#
# Tamamlandı: Maxi_Tum_0411_015801.txt
#
# Tamamlandı: Maxi_Tum_0411_015804.txt
#
# Tamamlandı: Maxi_Tum_0411_015807.txt
#
# Tamamlandı: Maxi_Tum_0411_015810.txt
#
# Tamamlandı: Maxi_Tum_0411_015813.txt
#
# Tamamlandı: Maxi_Tum_0411_015816.txt
#
# Tamamlandı: Maxi_Tum_0411_015819.txt
#
# Tamamlandı: Maxi_Tum_0411_015822.txt
#
# Tamamlandı: Maxi_Tum_0411_015825.txt
#
# Tamamlandı: Maxi_Tum_0411_015828.txt
#
# Tamamlandı: Maxi_Tum_0411_015831.txt
#
# Tamamlandı: Maxi_Tum_0411_015834.txt
#
# Tamamlandı: Maxi_Tum_0411_015837.txt
#
# Tamamlandı: Maxi_Tum_0411_015840.txt
#
# Tamamlandı: Maxi_Tum_0411_015843.txt
#
# [Maxi_Tum_0411_015846.txt] Silinen: 5 0.3059766054153442 0.3702666671187789 0.4204759120941162 0.7405333342375578  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015846.txt
#
# Tamamlandı: Maxi_Tum_0411_015849.txt
#
# Tamamlandı: Maxi_Tum_0411_015852.txt
#
# [Maxi_Tum_0411_015855.txt] Silinen: 5 0.4472445170084635 0.38087983308015044 0.45227584838867185 0.7617596661603009  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015855.txt
#
# Tamamlandı: Maxi_Tum_0411_015858.txt
#
# [Maxi_Tum_0411_015861.txt] Silinen: 5 0.5382876714070638 0.3875374688042535 0.4588481903076172 0.775074937608507  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_015861.txt
#
# Tamamlandı: Maxi_Tum_0411_015864.txt
#
# Tamamlandı: Maxi_Tum_0411_015867.txt
#
# Tamamlandı: Maxi_Tum_0411_015870.txt
#
# Tamamlandı: Maxi_Tum_0411_015873.txt
#
# Tamamlandı: Maxi_Tum_0411_015876.txt
#
# Tamamlandı: Maxi_Tum_0411_015879.txt
#
# [Maxi_Tum_0411_015882.txt] Silinen: 5 0.816278584798177 0.405905999077691 0.35659942626953123 0.7262308756510417  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_015882.txt
#
# Tamamlandı: Maxi_Tum_0411_015885.txt
#
# Tamamlandı: Maxi_Tum_0411_015888.txt
#
# Tamamlandı: Maxi_Tum_0411_015891.txt
#
# Tamamlandı: Maxi_Tum_0411_015894.txt
#
# Tamamlandı: Maxi_Tum_0411_015897.txt
#
# Tamamlandı: Maxi_Tum_0411_015900.txt
#
# Tamamlandı: Maxi_Tum_0411_015903.txt
#
# Tamamlandı: Maxi_Tum_0411_015906.txt
#
# Tamamlandı: Maxi_Tum_0411_015909.txt
#
# Tamamlandı: Maxi_Tum_0411_015912.txt
#
# Tamamlandı: Maxi_Tum_0411_015915.txt
#
# Tamamlandı: Maxi_Tum_0411_015918.txt
#
# Tamamlandı: Maxi_Tum_0411_015921.txt
#
# Tamamlandı: Maxi_Tum_0411_015924.txt
#
# Tamamlandı: Maxi_Tum_0411_015927.txt
#
# Tamamlandı: Maxi_Tum_0411_015930.txt
#
# Tamamlandı: Maxi_Tum_0411_015933.txt
#
# Tamamlandı: Maxi_Tum_0411_015936.txt
#
# Tamamlandı: Maxi_Tum_0411_015939.txt
#
# Tamamlandı: Maxi_Tum_0411_015942.txt
#
# Tamamlandı: Maxi_Tum_0411_015945.txt
#
# Tamamlandı: Maxi_Tum_0411_015948.txt
#
# Tamamlandı: Maxi_Tum_0411_015951.txt
#
# Tamamlandı: Maxi_Tum_0411_015954.txt
#
# Tamamlandı: Maxi_Tum_0411_015957.txt
#
# Tamamlandı: Maxi_Tum_0411_015960.txt
#
# Tamamlandı: Maxi_Tum_0411_015963.txt
#
# Tamamlandı: Maxi_Tum_0411_015966.txt
#
# Tamamlandı: Maxi_Tum_0411_015969.txt
#
# Tamamlandı: Maxi_Tum_0411_015972.txt
#
# Tamamlandı: Maxi_Tum_0411_015975.txt
#
# Tamamlandı: Maxi_Tum_0411_015978.txt
#
# Tamamlandı: Maxi_Tum_0411_015981.txt
#
# Tamamlandı: Maxi_Tum_0411_015984.txt
#
# Tamamlandı: Maxi_Tum_0411_015987.txt
#
# Tamamlandı: Maxi_Tum_0411_015990.txt
#
# Tamamlandı: Maxi_Tum_0411_015993.txt
#
# Tamamlandı: Maxi_Tum_0411_015996.txt
#
# Tamamlandı: Maxi_Tum_0411_015999.txt
#
# Tamamlandı: Maxi_Tum_0411_016002.txt
#
# Tamamlandı: Maxi_Tum_0411_016005.txt
#
# Tamamlandı: Maxi_Tum_0411_016008.txt
#
# Tamamlandı: Maxi_Tum_0411_016011.txt
#
# Tamamlandı: Maxi_Tum_0411_016014.txt
#
# Tamamlandı: Maxi_Tum_0411_016017.txt
#
# Tamamlandı: Maxi_Tum_0411_016020.txt
#
# Tamamlandı: Maxi_Tum_0411_016023.txt
#
# Tamamlandı: Maxi_Tum_0411_016026.txt
#
# Tamamlandı: Maxi_Tum_0411_016029.txt
#
# Tamamlandı: Maxi_Tum_0411_016032.txt
#
# Tamamlandı: Maxi_Tum_0411_016035.txt
#
# Tamamlandı: Maxi_Tum_0411_016038.txt
#
# Tamamlandı: Maxi_Tum_0411_016041.txt
#
# Tamamlandı: Maxi_Tum_0411_016044.txt
#
# Tamamlandı: Maxi_Tum_0411_016047.txt
#
# Tamamlandı: Maxi_Tum_0411_016050.txt
#
# Tamamlandı: Maxi_Tum_0411_016053.txt
#
# Tamamlandı: Maxi_Tum_0411_016056.txt
#
# Tamamlandı: Maxi_Tum_0411_016059.txt
#
# Tamamlandı: Maxi_Tum_0411_016062.txt
#
# Tamamlandı: Maxi_Tum_0411_016065.txt
#
# Tamamlandı: Maxi_Tum_0411_016068.txt
#
# Tamamlandı: Maxi_Tum_0411_016071.txt
#
# Tamamlandı: Maxi_Tum_0411_016074.txt
#
# Tamamlandı: Maxi_Tum_0411_016077.txt
#
# Tamamlandı: Maxi_Tum_0411_016080.txt
#
# Tamamlandı: Maxi_Tum_0411_016083.txt
#
# Tamamlandı: Maxi_Tum_0411_016086.txt
#
# Tamamlandı: Maxi_Tum_0411_016089.txt
#
# Tamamlandı: Maxi_Tum_0411_016092.txt
#
# Tamamlandı: Maxi_Tum_0411_016095.txt
#
# Tamamlandı: Maxi_Tum_0411_016098.txt
#
# Tamamlandı: Maxi_Tum_0411_016101.txt
#
# Tamamlandı: Maxi_Tum_0411_016104.txt
#
# Tamamlandı: Maxi_Tum_0411_016107.txt
#
# Tamamlandı: Maxi_Tum_0411_016110.txt
#
# Tamamlandı: Maxi_Tum_0411_016113.txt
#
# Tamamlandı: Maxi_Tum_0411_016116.txt
#
# Tamamlandı: Maxi_Tum_0411_016119.txt
#
# Tamamlandı: Maxi_Tum_0411_016122.txt
#
# Tamamlandı: Maxi_Tum_0411_016125.txt
#
# Tamamlandı: Maxi_Tum_0411_016128.txt
#
# Tamamlandı: Maxi_Tum_0411_016131.txt
#
# Tamamlandı: Maxi_Tum_0411_016134.txt
#
# Tamamlandı: Maxi_Tum_0411_016137.txt
#
# Tamamlandı: Maxi_Tum_0411_016140.txt
#
# Tamamlandı: Maxi_Tum_0411_016143.txt
#
# Tamamlandı: Maxi_Tum_0411_016146.txt
#
# Tamamlandı: Maxi_Tum_0411_016149.txt
#
# Tamamlandı: Maxi_Tum_0411_016152.txt
#
# Tamamlandı: Maxi_Tum_0411_016155.txt
#
# Tamamlandı: Maxi_Tum_0411_016158.txt
#
# Tamamlandı: Maxi_Tum_0411_016161.txt
#
# Tamamlandı: Maxi_Tum_0411_016164.txt
#
# Tamamlandı: Maxi_Tum_0411_016167.txt
#
# Tamamlandı: Maxi_Tum_0411_016170.txt
#
# Tamamlandı: Maxi_Tum_0411_016173.txt
#
# Tamamlandı: Maxi_Tum_0411_016176.txt
#
# Tamamlandı: Maxi_Tum_0411_016179.txt
#
# Tamamlandı: Maxi_Tum_0411_016182.txt
#
# Tamamlandı: Maxi_Tum_0411_016185.txt
#
# Tamamlandı: Maxi_Tum_0411_016188.txt
#
# Tamamlandı: Maxi_Tum_0411_016191.txt
#
# Tamamlandı: Maxi_Tum_0411_016194.txt
#
# Tamamlandı: Maxi_Tum_0411_016197.txt
#
# Tamamlandı: Maxi_Tum_0411_016200.txt
#
# Tamamlandı: Maxi_Tum_0411_016203.txt
#
# Tamamlandı: Maxi_Tum_0411_016206.txt
#
# Tamamlandı: Maxi_Tum_0411_016209.txt
#
# Tamamlandı: Maxi_Tum_0411_016212.txt
#
# Tamamlandı: Maxi_Tum_0411_016215.txt
#
# Tamamlandı: Maxi_Tum_0411_016218.txt
#
# Tamamlandı: Maxi_Tum_0411_016221.txt
#
# Tamamlandı: Maxi_Tum_0411_016224.txt
#
# Tamamlandı: Maxi_Tum_0411_016227.txt
#
# Tamamlandı: Maxi_Tum_0411_016230.txt
#
# Tamamlandı: Maxi_Tum_0411_016233.txt
#
# Tamamlandı: Maxi_Tum_0411_016236.txt
#
# Tamamlandı: Maxi_Tum_0411_016239.txt
#
# Tamamlandı: Maxi_Tum_0411_016242.txt
#
# Tamamlandı: Maxi_Tum_0411_016245.txt
#
# Tamamlandı: Maxi_Tum_0411_016248.txt
#
# Tamamlandı: Maxi_Tum_0411_016251.txt
#
# Tamamlandı: Maxi_Tum_0411_016254.txt
#
# Tamamlandı: Maxi_Tum_0411_016257.txt
#
# Tamamlandı: Maxi_Tum_0411_016260.txt
#
# Tamamlandı: Maxi_Tum_0411_016263.txt
#
# Tamamlandı: Maxi_Tum_0411_016266.txt
#
# Tamamlandı: Maxi_Tum_0411_016269.txt
#
# Tamamlandı: Maxi_Tum_0411_016272.txt
#
# Tamamlandı: Maxi_Tum_0411_016275.txt
#
# [Maxi_Tum_0411_016278.txt] Silinen: 13 0.7056645393371582 0.3995695891203704 0.41650638580322263 0.7539033112702547  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_016278.txt
#
# Tamamlandı: Maxi_Tum_0411_016281.txt
#
# Tamamlandı: Maxi_Tum_0411_016284.txt
#
# Tamamlandı: Maxi_Tum_0411_016287.txt
#
# Tamamlandı: Maxi_Tum_0411_016290.txt
#
# Tamamlandı: Maxi_Tum_0411_016293.txt
#
# Tamamlandı: Maxi_Tum_0411_016296.txt
#
# Tamamlandı: Maxi_Tum_0411_016299.txt
#
# Tamamlandı: Maxi_Tum_0411_016302.txt
#
# Tamamlandı: Maxi_Tum_0411_016305.txt
#
# Tamamlandı: Maxi_Tum_0411_016308.txt
#
# Tamamlandı: Maxi_Tum_0411_016311.txt
#
# Tamamlandı: Maxi_Tum_0411_016314.txt
#
# Tamamlandı: Maxi_Tum_0411_016317.txt
#
# Tamamlandı: Maxi_Tum_0411_016320.txt
#
# Tamamlandı: Maxi_Tum_0411_016323.txt
#
# Tamamlandı: Maxi_Tum_0411_016326.txt
#
# Tamamlandı: Maxi_Tum_0411_016329.txt
#
# Tamamlandı: Maxi_Tum_0411_016332.txt
#
# Tamamlandı: Maxi_Tum_0411_016335.txt
#
# Tamamlandı: Maxi_Tum_0411_016338.txt
#
# Tamamlandı: Maxi_Tum_0411_016341.txt
#
# Tamamlandı: Maxi_Tum_0411_016344.txt
#
# Tamamlandı: Maxi_Tum_0411_016347.txt
#
# Tamamlandı: Maxi_Tum_0411_016350.txt
#
# Tamamlandı: Maxi_Tum_0411_016353.txt
#
# Tamamlandı: Maxi_Tum_0411_016356.txt
#
# Tamamlandı: Maxi_Tum_0411_016359.txt
#
# Tamamlandı: Maxi_Tum_0411_016362.txt
#
# Tamamlandı: Maxi_Tum_0411_016365.txt
#
# Tamamlandı: Maxi_Tum_0411_016368.txt
#
# Tamamlandı: Maxi_Tum_0411_016371.txt
#
# Tamamlandı: Maxi_Tum_0411_016374.txt
#
# Tamamlandı: Maxi_Tum_0411_016377.txt
#
# Tamamlandı: Maxi_Tum_0411_016380.txt
#
# Tamamlandı: Maxi_Tum_0411_016383.txt
#
# Tamamlandı: Maxi_Tum_0411_016386.txt
#
# Tamamlandı: Maxi_Tum_0411_016389.txt
#
# Tamamlandı: Maxi_Tum_0411_016392.txt
#
# Tamamlandı: Maxi_Tum_0411_016395.txt
#
# Tamamlandı: Maxi_Tum_0411_016398.txt
#
# Tamamlandı: Maxi_Tum_0411_016401.txt
#
# Tamamlandı: Maxi_Tum_0411_016404.txt
#
# Tamamlandı: Maxi_Tum_0411_016407.txt
#
# Tamamlandı: Maxi_Tum_0411_016410.txt
#
# Tamamlandı: Maxi_Tum_0411_016413.txt
#
# Tamamlandı: Maxi_Tum_0411_016416.txt
#
# Tamamlandı: Maxi_Tum_0411_016419.txt
#
# Tamamlandı: Maxi_Tum_0411_016422.txt
#
# Tamamlandı: Maxi_Tum_0411_016425.txt
#
# Tamamlandı: Maxi_Tum_0411_016428.txt
#
# Tamamlandı: Maxi_Tum_0411_016431.txt
#
# Tamamlandı: Maxi_Tum_0411_016434.txt
#
# Tamamlandı: Maxi_Tum_0411_016437.txt
#
# Tamamlandı: Maxi_Tum_0411_016440.txt
#
# Tamamlandı: Maxi_Tum_0411_016443.txt
#
# Tamamlandı: Maxi_Tum_0411_016446.txt
#
# Tamamlandı: Maxi_Tum_0411_016449.txt
#
# Tamamlandı: Maxi_Tum_0411_016452.txt
#
# Tamamlandı: Maxi_Tum_0411_016455.txt
#
# Tamamlandı: Maxi_Tum_0411_016458.txt
#
# Tamamlandı: Maxi_Tum_0411_016461.txt
#
# Tamamlandı: Maxi_Tum_0411_016464.txt
#
# Tamamlandı: Maxi_Tum_0411_016467.txt
#
# Tamamlandı: Maxi_Tum_0411_016470.txt
#
# Tamamlandı: Maxi_Tum_0411_016473.txt
#
# Tamamlandı: Maxi_Tum_0411_016476.txt
#
# Tamamlandı: Maxi_Tum_0411_016479.txt
#
# Tamamlandı: Maxi_Tum_0411_016482.txt
#
# Tamamlandı: Maxi_Tum_0411_016485.txt
#
# Tamamlandı: Maxi_Tum_0411_016488.txt
#
# Tamamlandı: Maxi_Tum_0411_016491.txt
#
# Tamamlandı: Maxi_Tum_0411_016494.txt
#
# Tamamlandı: Maxi_Tum_0411_016497.txt
#
# Tamamlandı: Maxi_Tum_0411_016500.txt
#
# Tamamlandı: Maxi_Tum_0411_016503.txt
#
# Tamamlandı: Maxi_Tum_0411_016506.txt
#
# Tamamlandı: Maxi_Tum_0411_016509.txt
#
# Tamamlandı: Maxi_Tum_0411_016512.txt
#
# Tamamlandı: Maxi_Tum_0411_016515.txt
#
# Tamamlandı: Maxi_Tum_0411_016518.txt
#
# Tamamlandı: Maxi_Tum_0411_016521.txt
#
# Tamamlandı: Maxi_Tum_0411_016524.txt
#
# Tamamlandı: Maxi_Tum_0411_016527.txt
#
# Tamamlandı: Maxi_Tum_0411_016530.txt
#
# Tamamlandı: Maxi_Tum_0411_016533.txt
#
# Tamamlandı: Maxi_Tum_0411_016536.txt
#
# Tamamlandı: Maxi_Tum_0411_016539.txt
#
# Tamamlandı: Maxi_Tum_0411_016542.txt
#
# Tamamlandı: Maxi_Tum_0411_016545.txt
#
# Tamamlandı: Maxi_Tum_0411_016548.txt
#
# Tamamlandı: Maxi_Tum_0411_016551.txt
#
# Tamamlandı: Maxi_Tum_0411_016554.txt
#
# Tamamlandı: Maxi_Tum_0411_016557.txt
#
# Tamamlandı: Maxi_Tum_0411_016560.txt
#
# Tamamlandı: Maxi_Tum_0411_016563.txt
#
# Tamamlandı: Maxi_Tum_0411_016566.txt
#
# Tamamlandı: Maxi_Tum_0411_016569.txt
#
# Tamamlandı: Maxi_Tum_0411_016572.txt
#
# Tamamlandı: Maxi_Tum_0411_016575.txt
#
# Tamamlandı: Maxi_Tum_0411_016578.txt
#
# Tamamlandı: Maxi_Tum_0411_016581.txt
#
# Tamamlandı: Maxi_Tum_0411_016584.txt
#
# Tamamlandı: Maxi_Tum_0411_016587.txt
#
# Tamamlandı: Maxi_Tum_0411_016590.txt
#
# Tamamlandı: Maxi_Tum_0411_016593.txt
#
# Tamamlandı: Maxi_Tum_0411_016596.txt
#
# Tamamlandı: Maxi_Tum_0411_016599.txt
#
# Tamamlandı: Maxi_Tum_0411_016602.txt
#
# Tamamlandı: Maxi_Tum_0411_016605.txt
#
# Tamamlandı: Maxi_Tum_0411_016608.txt
#
# Tamamlandı: Maxi_Tum_0411_016611.txt
#
# Tamamlandı: Maxi_Tum_0411_016614.txt
#
# Tamamlandı: Maxi_Tum_0411_016617.txt
#
# [Maxi_Tum_0411_016620.txt] Silinen: 13 0.4389089028040568 0.37692718505859374 0.45783384641011554 0.7538543701171875  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_016620.txt
#
# Tamamlandı: Maxi_Tum_0411_016623.txt
#
# Tamamlandı: Maxi_Tum_0411_016626.txt
#
# Tamamlandı: Maxi_Tum_0411_016629.txt
#
# Tamamlandı: Maxi_Tum_0411_016632.txt
#
# Tamamlandı: Maxi_Tum_0411_016635.txt
#
# Tamamlandı: Maxi_Tum_0411_016638.txt
#
# Tamamlandı: Maxi_Tum_0411_016641.txt
#
# Tamamlandı: Maxi_Tum_0411_016644.txt
#
# [Maxi_Tum_0411_016647.txt] Silinen: 4 0.8244250615437826 0.3912642584906684 0.3511498769124349 0.7188362969292534  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_016647.txt
#
# Tamamlandı: Maxi_Tum_0411_016650.txt
#
# Tamamlandı: Maxi_Tum_0411_016653.txt
#
# Tamamlandı: Maxi_Tum_0411_016656.txt
#
# Tamamlandı: Maxi_Tum_0411_016659.txt
#
# Tamamlandı: Maxi_Tum_0411_016662.txt
#
# Tamamlandı: Maxi_Tum_0411_016665.txt
#
# Tamamlandı: Maxi_Tum_0411_016668.txt
#
# Tamamlandı: Maxi_Tum_0411_016671.txt
#
# Tamamlandı: Maxi_Tum_0411_016674.txt
#
# Tamamlandı: Maxi_Tum_0411_016677.txt
#
# Tamamlandı: Maxi_Tum_0411_016680.txt
#
# Tamamlandı: Maxi_Tum_0411_016683.txt
#
# Tamamlandı: Maxi_Tum_0411_016686.txt
#
# Tamamlandı: Maxi_Tum_0411_016689.txt
#
# Tamamlandı: Maxi_Tum_0411_016692.txt
#
# Tamamlandı: Maxi_Tum_0411_016695.txt
#
# Tamamlandı: Maxi_Tum_0411_016698.txt
#
# Tamamlandı: Maxi_Tum_0411_016701.txt
#
# Tamamlandı: Maxi_Tum_0411_016704.txt
#
# Tamamlandı: Maxi_Tum_0411_016707.txt
#
# Tamamlandı: Maxi_Tum_0411_016710.txt
#
# Tamamlandı: Maxi_Tum_0411_016713.txt
#
# Tamamlandı: Maxi_Tum_0411_016716.txt
#
# Tamamlandı: Maxi_Tum_0411_016719.txt
#
# Tamamlandı: Maxi_Tum_0411_016722.txt
#
# Tamamlandı: Maxi_Tum_0411_016725.txt
#
# Tamamlandı: Maxi_Tum_0411_016728.txt
#
# Tamamlandı: Maxi_Tum_0411_016731.txt
#
# Tamamlandı: Maxi_Tum_0411_016734.txt
#
# Tamamlandı: Maxi_Tum_0411_016737.txt
#
# Tamamlandı: Maxi_Tum_0411_016740.txt
#
# Tamamlandı: Maxi_Tum_0411_016743.txt
#
# Tamamlandı: Maxi_Tum_0411_016746.txt
#
# Tamamlandı: Maxi_Tum_0411_016749.txt
#
# Tamamlandı: Maxi_Tum_0411_016752.txt
#
# Tamamlandı: Maxi_Tum_0411_016755.txt
#
# Tamamlandı: Maxi_Tum_0411_016758.txt
#
# Tamamlandı: Maxi_Tum_0411_016761.txt
#
# Tamamlandı: Maxi_Tum_0411_016764.txt
#
# Tamamlandı: Maxi_Tum_0411_016767.txt
#
# Tamamlandı: Maxi_Tum_0411_016770.txt
#
# Tamamlandı: Maxi_Tum_0411_016773.txt
#
# Tamamlandı: Maxi_Tum_0411_016776.txt
#
# Tamamlandı: Maxi_Tum_0411_016779.txt
#
# Tamamlandı: Maxi_Tum_0411_016782.txt
#
# Tamamlandı: Maxi_Tum_0411_016785.txt
#
# Tamamlandı: Maxi_Tum_0411_016788.txt
#
# Tamamlandı: Maxi_Tum_0411_016791.txt
#
# Tamamlandı: Maxi_Tum_0411_016794.txt
#
# Tamamlandı: Maxi_Tum_0411_016797.txt
#
# Tamamlandı: Maxi_Tum_0411_016800.txt
#
# Tamamlandı: Maxi_Tum_0411_016803.txt
#
# Tamamlandı: Maxi_Tum_0411_016806.txt
#
# Tamamlandı: Maxi_Tum_0411_016809.txt
#
# Tamamlandı: Maxi_Tum_0411_016812.txt
#
# Tamamlandı: Maxi_Tum_0411_016815.txt
#
# Tamamlandı: Maxi_Tum_0411_016818.txt
#
# Tamamlandı: Maxi_Tum_0411_016821.txt
#
# Tamamlandı: Maxi_Tum_0411_016824.txt
#
# Tamamlandı: Maxi_Tum_0411_016827.txt
#
# Tamamlandı: Maxi_Tum_0411_016830.txt
#
# Tamamlandı: Maxi_Tum_0411_016833.txt
#
# Tamamlandı: Maxi_Tum_0411_016836.txt
#
# Tamamlandı: Maxi_Tum_0411_016839.txt
#
# Tamamlandı: Maxi_Tum_0411_016842.txt
#
# Tamamlandı: Maxi_Tum_0411_016845.txt
#
# Tamamlandı: Maxi_Tum_0411_016848.txt
#
# Tamamlandı: Maxi_Tum_0411_016851.txt
#
# Tamamlandı: Maxi_Tum_0411_016854.txt
#
# Tamamlandı: Maxi_Tum_0411_016857.txt
#
# Tamamlandı: Maxi_Tum_0411_016860.txt
#
# Tamamlandı: Maxi_Tum_0411_016863.txt
#
# Tamamlandı: Maxi_Tum_0411_016866.txt
#
# Tamamlandı: Maxi_Tum_0411_016869.txt
#
# Tamamlandı: Maxi_Tum_0411_016872.txt
#
# Tamamlandı: Maxi_Tum_0411_016875.txt
#
# Tamamlandı: Maxi_Tum_0411_016878.txt
#
# Tamamlandı: Maxi_Tum_0411_016881.txt
#
# Tamamlandı: Maxi_Tum_0411_016884.txt
#
# Tamamlandı: Maxi_Tum_0411_016887.txt
#
# Tamamlandı: Maxi_Tum_0411_016890.txt
#
# Tamamlandı: Maxi_Tum_0411_016893.txt
#
# Tamamlandı: Maxi_Tum_0411_016896.txt
#
# Tamamlandı: Maxi_Tum_0411_016899.txt
#
# Tamamlandı: Maxi_Tum_0411_016902.txt
#
# Tamamlandı: Maxi_Tum_0411_016905.txt
#
# Tamamlandı: Maxi_Tum_0411_016908.txt
#
# Tamamlandı: Maxi_Tum_0411_016911.txt
#
# Tamamlandı: Maxi_Tum_0411_016914.txt
#
# Tamamlandı: Maxi_Tum_0411_016917.txt
#
# Tamamlandı: Maxi_Tum_0411_016920.txt
#
# Tamamlandı: Maxi_Tum_0411_016923.txt
#
# Tamamlandı: Maxi_Tum_0411_016926.txt
#
# Tamamlandı: Maxi_Tum_0411_016929.txt
#
# Tamamlandı: Maxi_Tum_0411_016932.txt
#
# Tamamlandı: Maxi_Tum_0411_016935.txt
#
# Tamamlandı: Maxi_Tum_0411_016938.txt
#
# Tamamlandı: Maxi_Tum_0411_016941.txt
#
# Tamamlandı: Maxi_Tum_0411_016944.txt
#
# Tamamlandı: Maxi_Tum_0411_016947.txt
#
# Tamamlandı: Maxi_Tum_0411_016950.txt
#
# Tamamlandı: Maxi_Tum_0411_016953.txt
#
# Tamamlandı: Maxi_Tum_0411_016956.txt
#
# Tamamlandı: Maxi_Tum_0411_016959.txt
#
# Tamamlandı: Maxi_Tum_0411_016962.txt
#
# Tamamlandı: Maxi_Tum_0411_016965.txt
#
# Tamamlandı: Maxi_Tum_0411_016968.txt
#
# Tamamlandı: Maxi_Tum_0411_016971.txt
#
# Tamamlandı: Maxi_Tum_0411_016974.txt
#
# Tamamlandı: Maxi_Tum_0411_016977.txt
#
# Tamamlandı: Maxi_Tum_0411_016980.txt
#
# Tamamlandı: Maxi_Tum_0411_016983.txt
#
# Tamamlandı: Maxi_Tum_0411_016986.txt
#
# Tamamlandı: Maxi_Tum_0411_016989.txt
#
# Tamamlandı: Maxi_Tum_0411_016992.txt
#
# Tamamlandı: Maxi_Tum_0411_016995.txt
#
# Tamamlandı: Maxi_Tum_0411_016998.txt
#
# Tamamlandı: Maxi_Tum_0411_017001.txt
#
# Tamamlandı: Maxi_Tum_0411_017004.txt
#
# Tamamlandı: Maxi_Tum_0411_017007.txt
#
# Tamamlandı: Maxi_Tum_0411_017010.txt
#
# Tamamlandı: Maxi_Tum_0411_017013.txt
#
# Tamamlandı: Maxi_Tum_0411_017016.txt
#
# Tamamlandı: Maxi_Tum_0411_017019.txt
#
# Tamamlandı: Maxi_Tum_0411_017022.txt
#
# Tamamlandı: Maxi_Tum_0411_017025.txt
#
# Tamamlandı: Maxi_Tum_0411_017028.txt
#
# Tamamlandı: Maxi_Tum_0411_017031.txt
#
# Tamamlandı: Maxi_Tum_0411_017034.txt
#
# Tamamlandı: Maxi_Tum_0411_017037.txt
#
# Tamamlandı: Maxi_Tum_0411_017040.txt
#
# Tamamlandı: Maxi_Tum_0411_017043.txt
#
# Tamamlandı: Maxi_Tum_0411_017046.txt
#
# Tamamlandı: Maxi_Tum_0411_017049.txt
#
# Tamamlandı: Maxi_Tum_0411_017052.txt
#
# [Maxi_Tum_0411_017055.txt] Silinen: 30 0.20033643245697022 0.40085771348741317 0.36823086738586425 0.7268385145399305  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_017055.txt
#
# Tamamlandı: Maxi_Tum_0411_017058.txt
#
# Tamamlandı: Maxi_Tum_0411_017061.txt
#
# [Maxi_Tum_0411_017064.txt] Silinen: 4 0.31628496646881105 0.3952933841281467 0.434981107711792 0.744783443874783  (IoU=0.96)
# Tamamlandı: Maxi_Tum_0411_017064.txt
#
# [Maxi_Tum_0411_017067.txt] Silinen: 4 0.36513368288675946 0.3933816132722078 0.44669631322224934 0.7593119868525753  (IoU=0.99)
# [Maxi_Tum_0411_017067.txt] Silinen: 13 0.365523632367452 0.3915788721155237 0.4459967772165934 0.7670834576642072  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_017067.txt
#
# [Maxi_Tum_0411_017070.txt] Silinen: 13 0.39979159037272133 0.3958259582519531 0.45255940755208335 0.7644983927408854  (IoU=0.99)
# [Maxi_Tum_0411_017070.txt] Silinen: 5 0.39993074735005696 0.3957549907543041 0.4522340456644694 0.7698565730342158  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_017070.txt
#
# Tamamlandı: Maxi_Tum_0411_017073.txt
#
# Tamamlandı: Maxi_Tum_0411_017076.txt
#
# Tamamlandı: Maxi_Tum_0411_017079.txt
#
# [Maxi_Tum_0411_017082.txt] Silinen: 5 0.5831772645314535 0.3917850070529514 0.44973395665486654 0.7452704535590278  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_017082.txt
#
# Tamamlandı: Maxi_Tum_0411_017085.txt
#
# Tamamlandı: Maxi_Tum_0411_017088.txt
#
# [Maxi_Tum_0411_017091.txt] Silinen: 4 0.7181137084960938 0.4033921135796441 0.41796226501464845 0.7501127454969618  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_017091.txt
#
# Tamamlandı: Maxi_Tum_0411_017094.txt
#
# Tamamlandı: Maxi_Tum_0411_017097.txt
#
# Tamamlandı: Maxi_Tum_0411_017100.txt
#
# Tamamlandı: Maxi_Tum_0411_017103.txt
#
# Tamamlandı: Maxi_Tum_0411_017106.txt
#
# Tamamlandı: Maxi_Tum_0411_017109.txt
#
# Tamamlandı: Maxi_Tum_0411_017112.txt
#
# Tamamlandı: Maxi_Tum_0411_017115.txt
#
# Tamamlandı: Maxi_Tum_0411_017118.txt
#
# Tamamlandı: Maxi_Tum_0411_017121.txt
#
# Tamamlandı: Maxi_Tum_0411_017124.txt
#
# Tamamlandı: Maxi_Tum_0411_017127.txt
#
# Tamamlandı: Maxi_Tum_0411_017130.txt
#
# Tamamlandı: Maxi_Tum_0411_017133.txt
#
# Tamamlandı: Maxi_Tum_0411_017136.txt
#
# Tamamlandı: Maxi_Tum_0411_017139.txt
#
# Tamamlandı: Maxi_Tum_0411_017142.txt
#
# Tamamlandı: Maxi_Tum_0411_017145.txt
#
# Tamamlandı: Maxi_Tum_0411_017148.txt
#
# Tamamlandı: Maxi_Tum_0411_017151.txt
#
# Tamamlandı: Maxi_Tum_0411_017154.txt
#
# Tamamlandı: Maxi_Tum_0411_017157.txt
#
# Tamamlandı: Maxi_Tum_0411_017160.txt
#
# Tamamlandı: Maxi_Tum_0411_017163.txt
#
# Tamamlandı: Maxi_Tum_0411_017166.txt
#
# Tamamlandı: Maxi_Tum_0411_017169.txt
#
# Tamamlandı: Maxi_Tum_0411_017172.txt
#
# Tamamlandı: Maxi_Tum_0411_017175.txt
#
# Tamamlandı: Maxi_Tum_0411_017178.txt
#
# Tamamlandı: Maxi_Tum_0411_017181.txt
#
# Tamamlandı: Maxi_Tum_0411_017184.txt
#
# Tamamlandı: Maxi_Tum_0411_017187.txt
#
# Tamamlandı: Maxi_Tum_0411_017190.txt
#
# Tamamlandı: Maxi_Tum_0411_017193.txt
#
# Tamamlandı: Maxi_Tum_0411_017196.txt
#
# Tamamlandı: Maxi_Tum_0411_017199.txt
#
# Tamamlandı: Maxi_Tum_0411_017202.txt
#
# Tamamlandı: Maxi_Tum_0411_017205.txt
#
# Tamamlandı: Maxi_Tum_0411_017208.txt
#
# Tamamlandı: Maxi_Tum_0411_017211.txt
#
# Tamamlandı: Maxi_Tum_0411_017214.txt
#
# Tamamlandı: Maxi_Tum_0411_017217.txt
#
# Tamamlandı: Maxi_Tum_0411_017220.txt
#
# Tamamlandı: Maxi_Tum_0411_017223.txt
#
# Tamamlandı: Maxi_Tum_0411_017226.txt
#
# Tamamlandı: Maxi_Tum_0411_017229.txt
#
# Tamamlandı: Maxi_Tum_0411_017232.txt
#
# Tamamlandı: Maxi_Tum_0411_017235.txt
#
# Tamamlandı: Maxi_Tum_0411_017238.txt
#
# Tamamlandı: Maxi_Tum_0411_017241.txt
#
# Tamamlandı: Maxi_Tum_0411_017244.txt
#
# Tamamlandı: Maxi_Tum_0411_017247.txt
#
# Tamamlandı: Maxi_Tum_0411_017250.txt
#
# Tamamlandı: Maxi_Tum_0411_017253.txt
#
# Tamamlandı: Maxi_Tum_0411_017256.txt
#
# Tamamlandı: Maxi_Tum_0411_017259.txt
#
# Tamamlandı: Maxi_Tum_0411_017262.txt
#
# Tamamlandı: Maxi_Tum_0411_017265.txt
#
# Tamamlandı: Maxi_Tum_0411_017268.txt
#
# Tamamlandı: Maxi_Tum_0411_017271.txt
#
# Tamamlandı: Maxi_Tum_0411_017274.txt
#
# Tamamlandı: Maxi_Tum_0411_017277.txt
#
# Tamamlandı: Maxi_Tum_0411_017280.txt
#
# Tamamlandı: Maxi_Tum_0411_017283.txt
#
# Tamamlandı: Maxi_Tum_0411_017286.txt
#
# Tamamlandı: Maxi_Tum_0411_017289.txt
#
# Tamamlandı: Maxi_Tum_0411_017292.txt
#
# Tamamlandı: Maxi_Tum_0411_017295.txt
#
# Tamamlandı: Maxi_Tum_0411_017298.txt
#
# Tamamlandı: Maxi_Tum_0411_017301.txt
#
# Tamamlandı: Maxi_Tum_0411_017304.txt
#
# Tamamlandı: Maxi_Tum_0411_017307.txt
#
# Tamamlandı: Maxi_Tum_0411_017310.txt
#
# Tamamlandı: Maxi_Tum_0411_017313.txt
#
# Tamamlandı: Maxi_Tum_0411_017316.txt
#
# Tamamlandı: Maxi_Tum_0411_017319.txt
#
# Tamamlandı: Maxi_Tum_0411_017322.txt
#
# Tamamlandı: Maxi_Tum_0411_017325.txt
#
# Tamamlandı: Maxi_Tum_0411_017328.txt
#
# Tamamlandı: Maxi_Tum_0411_017331.txt
#
# Tamamlandı: Maxi_Tum_0411_017334.txt
#
# Tamamlandı: Maxi_Tum_0411_017337.txt
#
# Tamamlandı: Maxi_Tum_0411_017340.txt
#
# Tamamlandı: Maxi_Tum_0411_017343.txt
#
# Tamamlandı: Maxi_Tum_0411_017346.txt
#
# Tamamlandı: Maxi_Tum_0411_017349.txt
#
# Tamamlandı: Maxi_Tum_0411_017352.txt
#
# Tamamlandı: Maxi_Tum_0411_017355.txt
#
# Tamamlandı: Maxi_Tum_0411_017358.txt
#
# Tamamlandı: Maxi_Tum_0411_017361.txt
#
# Tamamlandı: Maxi_Tum_0411_017364.txt
#
# Tamamlandı: Maxi_Tum_0411_017367.txt
#
# Tamamlandı: Maxi_Tum_0411_017370.txt
#
# Tamamlandı: Maxi_Tum_0411_017373.txt
#
# Tamamlandı: Maxi_Tum_0411_017376.txt
#
# Tamamlandı: Maxi_Tum_0411_017379.txt
#
# Tamamlandı: Maxi_Tum_0411_017382.txt
#
# Tamamlandı: Maxi_Tum_0411_017385.txt
#
# Tamamlandı: Maxi_Tum_0411_017388.txt
#
# Tamamlandı: Maxi_Tum_0411_017391.txt
#
# Tamamlandı: Maxi_Tum_0411_017394.txt
#
# Tamamlandı: Maxi_Tum_0411_017397.txt
#
# Tamamlandı: Maxi_Tum_0411_017400.txt
#
# Tamamlandı: Maxi_Tum_0411_017403.txt
#
# Tamamlandı: Maxi_Tum_0411_017406.txt
#
# Tamamlandı: Maxi_Tum_0411_017409.txt
#
# Tamamlandı: Maxi_Tum_0411_017412.txt
#
# Tamamlandı: Maxi_Tum_0411_017415.txt
#
# Tamamlandı: Maxi_Tum_0411_017418.txt
#
# Tamamlandı: Maxi_Tum_0411_017421.txt
#
# Tamamlandı: Maxi_Tum_0411_017424.txt
#
# Tamamlandı: Maxi_Tum_0411_017427.txt
#
# Tamamlandı: Maxi_Tum_0411_017430.txt
#
# Tamamlandı: Maxi_Tum_0411_017433.txt
#
# Tamamlandı: Maxi_Tum_0411_017436.txt
#
# Tamamlandı: Maxi_Tum_0411_017439.txt
#
# Tamamlandı: Maxi_Tum_0411_017442.txt
#
# Tamamlandı: Maxi_Tum_0411_017445.txt
#
# Tamamlandı: Maxi_Tum_0411_017448.txt
#
# Tamamlandı: Maxi_Tum_0411_017451.txt
#
# Tamamlandı: Maxi_Tum_0411_017454.txt
#
# Tamamlandı: Maxi_Tum_0411_017457.txt
#
# Tamamlandı: Maxi_Tum_0411_017460.txt
#
# Tamamlandı: Maxi_Tum_0411_017463.txt
#
# Tamamlandı: Maxi_Tum_0411_017466.txt
#
# Tamamlandı: Maxi_Tum_0411_017469.txt
#
# Tamamlandı: Maxi_Tum_0411_017472.txt
#
# Tamamlandı: Maxi_Tum_0411_017475.txt
#
# Tamamlandı: Maxi_Tum_0411_017478.txt
#
# Tamamlandı: Maxi_Tum_0411_017481.txt
#
# Tamamlandı: Maxi_Tum_0411_017484.txt
#
# Tamamlandı: Maxi_Tum_0411_017487.txt
#
# Tamamlandı: Maxi_Tum_0411_017490.txt
#
# Tamamlandı: Maxi_Tum_0411_017493.txt
#
# Tamamlandı: Maxi_Tum_0411_017496.txt
#
# Tamamlandı: Maxi_Tum_0411_017499.txt
#
# Tamamlandı: Maxi_Tum_0411_017502.txt
#
# Tamamlandı: Maxi_Tum_0411_017505.txt
#
# Tamamlandı: Maxi_Tum_0411_017508.txt
#
# Tamamlandı: Maxi_Tum_0411_017511.txt
#
# Tamamlandı: Maxi_Tum_0411_017514.txt
#
# Tamamlandı: Maxi_Tum_0411_017517.txt
#
# [Maxi_Tum_0411_017520.txt] Silinen: 13 0.40549179712931316 0.40406755518030235 0.44810098012288413 0.7590955663610388  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_017520.txt
#
# Tamamlandı: Maxi_Tum_0411_017523.txt
#
# Tamamlandı: Maxi_Tum_0411_017526.txt
#
# Tamamlandı: Maxi_Tum_0411_017529.txt
#
# Tamamlandı: Maxi_Tum_0411_017532.txt
#
# Tamamlandı: Maxi_Tum_0411_017535.txt
#
# Tamamlandı: Maxi_Tum_0411_017538.txt
#
# Tamamlandı: Maxi_Tum_0411_017541.txt
#
# Tamamlandı: Maxi_Tum_0411_017544.txt
#
# Tamamlandı: Maxi_Tum_0411_017547.txt
#
# Tamamlandı: Maxi_Tum_0411_017550.txt
#
# Tamamlandı: Maxi_Tum_0411_017553.txt
#
# Tamamlandı: Maxi_Tum_0411_017556.txt
#
# Tamamlandı: Maxi_Tum_0411_017559.txt
#
# Tamamlandı: Maxi_Tum_0411_017562.txt
#
# Tamamlandı: Maxi_Tum_0411_017565.txt
#
# Tamamlandı: Maxi_Tum_0411_017568.txt
#
# Tamamlandı: Maxi_Tum_0411_017571.txt
#
# Tamamlandı: Maxi_Tum_0411_017574.txt
#
# Tamamlandı: Maxi_Tum_0411_017577.txt
#
# Tamamlandı: Maxi_Tum_0411_017580.txt
#
# Tamamlandı: Maxi_Tum_0411_017583.txt
#
# Tamamlandı: Maxi_Tum_0411_017586.txt
#
# Tamamlandı: Maxi_Tum_0411_017589.txt
#
# Tamamlandı: Maxi_Tum_0411_017592.txt
#
# Tamamlandı: Maxi_Tum_0411_017595.txt
#
# Tamamlandı: Maxi_Tum_0411_017598.txt
#
# Tamamlandı: Maxi_Tum_0411_017601.txt
#
# Tamamlandı: Maxi_Tum_0411_017604.txt
#
# Tamamlandı: Maxi_Tum_0411_017607.txt
#
# Tamamlandı: Maxi_Tum_0411_017610.txt
#
# Tamamlandı: Maxi_Tum_0411_017613.txt
#
# Tamamlandı: Maxi_Tum_0411_017616.txt
#
# Tamamlandı: Maxi_Tum_0411_017619.txt
#
# Tamamlandı: Maxi_Tum_0411_017622.txt
#
# [Maxi_Tum_0411_017625.txt] Silinen: 13 0.7206663290659586 0.38159603542751735 0.4118093808492025 0.7611829969618056  (IoU=0.98)
# Tamamlandı: Maxi_Tum_0411_017625.txt
#
# Tamamlandı: Maxi_Tum_0411_017628.txt
#
# Tamamlandı: Maxi_Tum_0411_017631.txt
#
# [Maxi_Tum_0411_017634.txt] Silinen: 1 0.8290283838907878 0.3999872560854311 0.3419432322184245 0.7233933625397859  (IoU=0.99)
# Tamamlandı: Maxi_Tum_0411_017634.txt
#
# Tamamlandı: Maxi_Tum_0411_017637.txt
#
# Tamamlandı: Maxi_Tum_0411_017640.txt
#
# Tamamlandı: Maxi_Tum_0411_017643.txt
#
# Tamamlandı: Maxi_Tum_0411_017646.txt
#
# Tamamlandı: Maxi_Tum_0411_017649.txt
#
# Tamamlandı: Maxi_Tum_0411_017652.txt
#
# Tamamlandı: Maxi_Tum_0411_017655.txt
#
# Tamamlandı: Maxi_Tum_0411_017658.txt
#
# Tamamlandı: Maxi_Tum_0411_017661.txt
#
# Tamamlandı: Maxi_Tum_0411_017664.txt
#
# Tamamlandı: Maxi_Tum_0411_017667.txt
#
# Tamamlandı: Maxi_Tum_0411_017670.txt
#
# Tamamlandı: Maxi_Tum_0411_017673.txt
#
# Tamamlandı: Maxi_Tum_0411_017676.txt
#
# Tamamlandı: Maxi_Tum_0411_017679.txt
#
# Tamamlandı: Maxi_Tum_0411_017682.txt
#
# Tamamlandı: Maxi_Tum_0411_017685.txt
#
# Tamamlandı: Maxi_Tum_0411_017688.txt
#
# Tamamlandı: Maxi_Tum_0411_017691.txt
#
# Tamamlandı: Maxi_Tum_0411_017694.txt
#
# Tamamlandı: Maxi_Tum_0411_017697.txt
#
# Tamamlandı: Maxi_Tum_0411_017700.txt
#
# Tamamlandı: Maxi_Tum_0411_017703.txt
#
# Tamamlandı: Maxi_Tum_0411_017706.txt
#
# Tamamlandı: Maxi_Tum_0411_017709.txt
#
# Tamamlandı: Maxi_Tum_0411_017712.txt
#
# Tamamlandı: Maxi_Tum_0411_017715.txt
#
# Tamamlandı: Maxi_Tum_0411_017718.txt
#
# Tamamlandı: Maxi_Tum_0411_017721.txt
#
# Tamamlandı: Maxi_Tum_0411_017724.txt
#
# Tamamlandı: Maxi_Tum_0411_017727.txt
#
# Tamamlandı: Maxi_Tum_0411_017730.txt
#
# Tamamlandı: Maxi_Tum_0411_017733.txt
#
# Tamamlandı: Maxi_Tum_0411_017736.txt
#
# Tamamlandı: Maxi_Tum_0411_017739.txt
#
# Tamamlandı: Maxi_Tum_0411_017742.txt
#
# Tamamlandı: Maxi_Tum_0411_017745.txt
#
# Tamamlandı: Maxi_Tum_0411_017748.txt
#
# Tamamlandı: Maxi_Tum_0411_017751.txt
#
# Tamamlandı: Maxi_Tum_0411_017754.txt
#
# Tamamlandı: Maxi_Tum_0411_017757.txt
#
# Tamamlandı: Maxi_Tum_0411_017760.txt
#
# Tamamlandı: Maxi_Tum_0411_017763.txt
#
# Tamamlandı: Maxi_Tum_0411_017766.txt
#
# Tamamlandı: Maxi_Tum_0411_017769.txt
#
# Tamamlandı: Maxi_Tum_0411_017772.txt
#
# Tamamlandı: Maxi_Tum_0411_017775.txt
#
# Tamamlandı: Maxi_Tum_0411_017778.txt
#
# Tamamlandı: Maxi_Tum_0411_017781.txt
#
# Tamamlandı: Maxi_Tum_0411_017784.txt
#
# Tamamlandı: Maxi_Tum_0411_017787.txt
#
# Tamamlandı: Maxi_Tum_0411_017790.txt
#
# Tamamlandı: Maxi_Tum_0411_017793.txt
#
# Tamamlandı: Maxi_Tum_0411_017796.txt
#
# Tamamlandı: Maxi_Tum_0411_017799.txt
#
# Tamamlandı: Maxi_Tum_0411_017802.txt
#
# Tamamlandı: Maxi_Tum_0411_017805.txt
#
# Tamamlandı: Maxi_Tum_0411_017808.txt
#
# Tamamlandı: Maxi_Tum_0411_017811.txt
#
# Tamamlandı: Maxi_Tum_0411_017814.txt
#
# Tamamlandı: Maxi_Tum_0411_017817.txt
#
# Tamamlandı: Maxi_Tum_0411_017820.txt
#
# Tamamlandı: Maxi_Tum_0411_017823.txt
#
# Tamamlandı: Maxi_Tum_0411_017826.txt
#
# Tamamlandı: Maxi_Tum_0411_017829.txt
#
# Tamamlandı: Maxi_Tum_0411_017832.txt
#
# Tamamlandı: Maxi_Tum_0411_017835.txt
#
# Tamamlandı: Maxi_Tum_0411_017838.txt
#
# Tamamlandı: Maxi_Tum_0411_017841.txt
#
# Tamamlandı: Maxi_Tum_0411_017844.txt
#
# Tamamlandı: Maxi_Tum_0411_017847.txt
#
# Tamamlandı: Maxi_Tum_0411_017850.txt
#
# Tamamlandı: Maxi_Tum_0411_017853.txt
#
# Tamamlandı: Maxi_Tum_0411_017856.txt
#
# Tamamlandı: Maxi_Tum_0411_017859.txt
#
# Tamamlandı: Maxi_Tum_0411_017862.txt
#
# Tamamlandı: Maxi_Tum_0411_017865.txt
#
# Tamamlandı: Maxi_Tum_0411_017868.txt
#
# Tamamlandı: Maxi_Tum_0411_017871.txt
#
# Tamamlandı: Maxi_Tum_0411_017874.txt
#
# Tamamlandı: Maxi_Tum_0411_017877.txt
#
# Tamamlandı: Maxi_Tum_0411_017880.txt
#
# Tamamlandı: Maxi_Tum_0411_017883.txt
#
# Tamamlandı: Maxi_Tum_0411_017886.txt
#
# Tamamlandı: Maxi_Tum_0411_017889.txt
#
# Tamamlandı: Maxi_Tum_0411_017892.txt
#
# Tamamlandı: Maxi_Tum_0411_017895.txt
#
# Tamamlandı: Maxi_Tum_0411_017898.txt
#
# Tamamlandı: Maxi_Tum_0411_017901.txt
#
# Tamamlandı: Maxi_Tum_0411_017904.txt
#
# Tamamlandı: Maxi_Tum_0411_017907.txt
#
# Tamamlandı: Maxi_Tum_0411_017910.txt
#
# Tamamlandı: Maxi_Tum_0411_017913.txt
#
# Tamamlandı: Maxi_Tum_0411_017916.txt
#
# Tamamlandı: Maxi_Tum_0411_017919.txt
#
# Tamamlandı: Maxi_Tum_0411_017922.txt
#
# Tamamlandı: Maxi_Tum_0411_017925.txt
#
# Tamamlandı: Maxi_Tum_0411_017928.txt
#
# Tamamlandı: Maxi_Tum_0411_017931.txt
#
# Tamamlandı: Maxi_Tum_0411_017934.txt
#
# Tamamlandı: Maxi_Tum_0411_017937.txt
#
# Tamamlandı: Maxi_Tum_0411_017940.txt
#
# Tamamlandı: Maxi_Tum_0411_017943.txt
#
# Tamamlandı: Maxi_Tum_0411_017946.txt
#
# Tamamlandı: Maxi_Tum_0411_017949.txt
#
# Tamamlandı: Maxi_Tum_0411_017952.txt
#
# Tamamlandı: Maxi_Tum_0411_017955.txt
#
# Tamamlandı: Maxi_Tum_0411_017958.txt
#
# Tamamlandı: Maxi_Tum_0411_017961.txt
#
# Tamamlandı: Maxi_Tum_0411_017964.txt
#
# Tamamlandı: Maxi_Tum_0411_017967.txt
#
# Tamamlandı: Maxi_Tum_0411_017970.txt
#
# Tamamlandı: Maxi_Tum_0411_017973.txt
#
# Tamamlandı: Maxi_Tum_0411_017976.txt
#
# Tamamlandı: Maxi_Tum_0411_017979.txt
#
# Tamamlandı: Maxi_Tum_0411_017982.txt
#
# Tamamlandı: Maxi_Tum_0411_017985.txt
#
# Tamamlandı: Maxi_Tum_0411_017988.txt
#
# Tamamlandı: Maxi_Tum_0411_017991.txt
#
# Tamamlandı: Maxi_Tum_0411_017994.txt
#
# Tamamlandı: Maxi_Tum_0411_017997.txt
#
# Tamamlandı: Maxi_Tum_0411_018000.txt
#
# Tamamlandı: Maxi_Tum_0411_018003.txt
#
# Tamamlandı: Maxi_Tum_0411_018006.txt
#
# Tamamlandı: Maxi_Tum_0411_018009.txt
#
# Tamamlandı: Maxi_Tum_0411_018012.txt
#
# Tamamlandı: Maxi_Tum_0411_018015.txt
#
# Tamamlandı: Maxi_Tum_0411_018018.txt
#
# Tamamlandı: Maxi_Tum_0411_018021.txt
#
# Tamamlandı: Maxi_Tum_0411_018024.txt
#
# Tamamlandı: Maxi_Tum_0411_018027.txt
#
# Tamamlandı: Maxi_Tum_0411_018030.txt
#
# Tamamlandı: Maxi_Tum_0411_018033.txt
#
# Tamamlandı: Maxi_Tum_0411_018036.txt
#
# Tamamlandı: Maxi_Tum_0411_018039.txt
#
# Tamamlandı: Maxi_Tum_0411_018042.txt
#
# Tamamlandı: Maxi_Tum_0411_018045.txt
#
# Tamamlandı: Maxi_Tum_0411_018048.txt
#
# Tamamlandı: Maxi_Tum_0411_018051.txt
#
# Tamamlandı: Maxi_Tum_0411_018054.txt
#
# Tamamlandı: Maxi_Tum_0411_018057.txt
#
# Tamamlandı: Maxi_Tum_0411_018060.txt
#
# Tamamlandı: Maxi_Tum_0411_018063.txt
#
# Tamamlandı: Maxi_Tum_0411_018066.txt
#
# Tamamlandı: Maxi_Tum_0411_018069.txt
#
# Tamamlandı: Maxi_Tum_0411_018072.txt
#
# Tamamlandı: Maxi_Tum_0411_018075.txt
#
# Tamamlandı: Maxi_Tum_0411_018078.txt
#
# Tamamlandı: Maxi_Tum_0411_018081.txt
#
# Tamamlandı: Maxi_Tum_0411_018084.txt
#
# Tamamlandı: Maxi_Tum_0411_018087.txt
#
# Tamamlandı: Maxi_Tum_0411_018090.txt
#
# Tamamlandı: Maxi_Tum_0411_018093.txt
#
# Tamamlandı: Maxi_Tum_0411_018096.txt
#
# Tamamlandı: Maxi_Tum_0411_018099.txt
#
# Tamamlandı: Maxi_Tum_0411_018102.txt
#
# Tamamlandı: Maxi_Tum_0411_018105.txt
#
# Tamamlandı: Maxi_Tum_0411_018108.txt
#
# Tamamlandı: Maxi_Tum_0411_018111.txt
#
# Tamamlandı: Maxi_Tum_0411_018114.txt
#
# Tamamlandı: Maxi_Tum_0411_018117.txt
#
# Tamamlandı: Maxi_Tum_0411_018120.txt
#
# Tamamlandı: Maxi_Tum_0411_018123.txt
#
# Tamamlandı: Maxi_Tum_0411_018126.txt
#
# Tamamlandı: Maxi_Tum_0411_018129.txt
#
# Tamamlandı: Maxi_Tum_0411_018132.txt
#
# Tamamlandı: Maxi_Tum_0411_018135.txt
#
# Tamamlandı: Maxi_Tum_0411_018138.txt
#
# Tamamlandı: Maxi_Tum_0411_018141.txt
#
# Tamamlandı: Maxi_Tum_0411_018144.txt
#
# Tamamlandı: Maxi_Tum_0411_018147.txt
#
# Tamamlandı: Maxi_Tum_0411_018150.txt
#
# Tamamlandı: Maxi_Tum_0411_018153.txt
#
# Tamamlandı: Maxi_Tum_0411_018156.txt
#
# Tamamlandı: Maxi_Tum_0411_018159.txt
#
# Tamamlandı: Maxi_Tum_0411_018162.txt
#
# Tamamlandı: Maxi_Tum_0411_018165.txt
#
# Tamamlandı: Maxi_Tum_0411_018168.txt
